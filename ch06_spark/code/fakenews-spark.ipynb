# %% [markdown]
# ## Bootstrap and setup dependencies

# %%
import pandas as pd
import nltk
import collections
import itertools
from collections import Counter
import tldextract
import numpy as np

#web
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import time
import json

#snorkel
from snorkel.labeling import labeling_function
#from snorkel.labeling import PandasLFApplier
from snorkel.labeling.apply.spark import SparkLFApplier
from snorkel.labeling.model import MajorityLabelVoter
from snorkel.labeling import LFAnalysis
from snorkel.labeling.model import LabelModel


ABSTAIN = -1
FAKE = 0
REAL = 1

## data filenames
TRAINING_dataFile = "/dbfs/FileStore/test/fnn_train.csv" #training dataset

API_RESULTS_dataFile = "/dbfs/FileStore/FNN/apiResults.csv" #Local csv that has the output of the fake news detection (FNN)

GB_dataFile = "/dbfs/FileStore/FNN/glennbeck_ratings.csv" # GlennGeck data files (www.glennbeck.com)
RP_dataFile = "/dbfs/FileStore/FNN/realclearpolitics_ratings.csv" # Realclear Politics file (www.realclearpolitics.com)
WP_dataFile = "/dbfs/FileStore/FNN/washingtonpost_ratings.csv" # Washington Post data file (www.washingtonpost.com/news/fact-checker)

# Load the Liar dataset
LIAR_dataFile = "/dbfs/FileStore/test/liar/liar_train.csv" #training dataset
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Initializing the sentiment analysis package

# %%
#In some cases a call later will fail, and this is needed on spark

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# </div>

# %% [markdown]
# ## Load the data

# %%
# Use panda to read CSV
data = pd.read_csv(TRAINING_dataFile, encoding='utf-8')

print("Count:", data.count())

#peek at the data
data.head(3)
#display(data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Count: id                         15212
# date                       15212
# speaker                    15212
# statement                  15212
# sources                    15212
# paragraph_based_content    15212
# fullText_based_content     15212
# label_fnn                  15212
# dtype: int64
# Out[3]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>date</th>
#       <th>speaker</th>
#       <th>statement</th>
#       <th>sources</th>
#       <th>paragraph_based_content</th>
#       <th>fullText_based_content</th>
#       <th>label_fnn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3106</td>
#       <td>2011-01-25T06:00:00-05:00</td>
#       <td>Joe Wilkinson</td>
#       <td>A national organization says Georgia has one o...</td>
#       <td>['http://www.ajc.com/news/georgia-politics-ele...</td>
#       <td>['A coalition of government watchdog groups la...</td>
#       <td>A coalition of government watchdog groups last...</td>
#       <td>fake</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5655</td>
#       <td>2012-04-02T11:42:20-04:00</td>
#       <td>Rick Scott</td>
#       <td>Says Barack Obama's health care law "will be t...</td>
#       <td>['http://www.youtube.com/watch?v=TaC0mKApf9Q&amp;f...</td>
#       <td>['As Supreme Court justices embarked on three ...</td>
#       <td>As Supreme Court justices embarked on three da...</td>
#       <td>fake</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3506</td>
#       <td>2011-04-01T09:49:05-04:00</td>
#       <td>J.D. Alexander</td>
#       <td>Says the Southwest Florida Water Management Di...</td>
#       <td>['http://www.tampabay.com/news/politics/gubern...</td>
#       <td>["Here's a new one: The Senate budget committe...</td>
#       <td>Here's a new one: The Senate budget committee ...</td>
#       <td>fake</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.info(verbose=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 15212 entries, 0 to 15211
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       15212 non-null  int64
#  1   date                     15212 non-null  object
#  2   speaker                  15212 non-null  object
#  3   statement                15212 non-null  object
#  4   sources                  15212 non-null  object
#  5   paragraph_based_content  15212 non-null  object
#  6   fullText_based_content   15212 non-null  object
#  7   label_fnn                15212 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 950.9+ KB
# </div>

# %%
#apiResultsFile = spark.read.csv(API_RESULTS_dataFile, header="false", inferSchema="true")
#apiResultsFile = pd.read_csv(API_RESULTS_dataFile, sep="|", encoding='utf-8', header=None)
#apiResultsFile.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Best to avoid pandas in spark but we trying to keep it consistent
# We replace the NaN with None for Spark
data = data.where(cond=data.notna(), other=None)
print("Count:", data.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Count: id                         15212
# date                       15212
# speaker                    15212
# statement                  15212
# sources                    15212
# paragraph_based_content    15212
# fullText_based_content     15212
# label_fnn                  15212
# dtype: int64
# </div>

# %% [markdown]
# ## Convert label to numbers; we can use the numbers validation

# %%
data["label_numeric"] = data.apply(lambda row: 1 if row["label_fnn"]=='real' else 0, axis=1)

#peek at the data
data.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>date</th>
#       <th>speaker</th>
#       <th>statement</th>
#       <th>sources</th>
#       <th>paragraph_based_content</th>
#       <th>fullText_based_content</th>
#       <th>label_fnn</th>
#       <th>label_numeric</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3106</td>
#       <td>2011-01-25T06:00:00-05:00</td>
#       <td>Joe Wilkinson</td>
#       <td>A national organization says Georgia has one o...</td>
#       <td>['http://www.ajc.com/news/georgia-politics-ele...</td>
#       <td>['A coalition of government watchdog groups la...</td>
#       <td>A coalition of government watchdog groups last...</td>
#       <td>fake</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5655</td>
#       <td>2012-04-02T11:42:20-04:00</td>
#       <td>Rick Scott</td>
#       <td>Says Barack Obama's health care law "will be t...</td>
#       <td>['http://www.youtube.com/watch?v=TaC0mKApf9Q&amp;f...</td>
#       <td>['As Supreme Court justices embarked on three ...</td>
#       <td>As Supreme Court justices embarked on three da...</td>
#       <td>fake</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3506</td>
#       <td>2011-04-01T09:49:05-04:00</td>
#       <td>J.D. Alexander</td>
#       <td>Says the Southwest Florida Water Management Di...</td>
#       <td>['http://www.tampabay.com/news/politics/gubern...</td>
#       <td>["Here's a new one: The Senate budget committe...</td>
#       <td>Here's a new one: The Senate budget committee ...</td>
#       <td>fake</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.info(verbose=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 15212 entries, 0 to 15211
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       15212 non-null  int64
#  1   date                     15212 non-null  object
#  2   speaker                  15212 non-null  object
#  3   statement                15212 non-null  object
#  4   sources                  15212 non-null  object
#  5   paragraph_based_content  15212 non-null  object
#  6   fullText_based_content   15212 non-null  object
#  7   label_fnn                15212 non-null  object
#  8   label_numeric            15212 non-null  int64
# dtypes: int64(2), object(7)
# memory usage: 1.0+ MB
# </div>

# %% [markdown]
# ## Retrieving labels / information from each site

# %%
# contacts a url, downloads the website's content and parses it.  
def get_parsed_html(url):
    req = Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage = urlopen(req).read()
    parsed_html = BeautifulSoup(webpage)
    return parsed_html
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.politifact.com

# %%
def get_poitifact_image_alt(url):
    result = "abstain"
    try:
        parsed_html = get_parsed_html(url)
        div = parsed_html.body.find('div', attrs={'class':'m-statement__meter'})
        result = div.find("img", attrs={'class':'c-image__original'})["alt"]
        time.sleep(0.5)
    except Exception as e:
        print(e)
    return result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.snopes.com

# %%
def get_snopes_image_alt(url):
    result = "abstain"
    try:
        parsed_html = get_parsed_html(url)
        div = parsed_html.body.find('div', attrs={'class':'media rating'})
        result = div.find("img")["alt"]
    except Exception as e:
        print(e)
    return result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.factcheck.org

# %%
def get_factcheck_first_paragraph(url):
    result = "abstain"
    try:
        parsed_html = get_parsed_html(url)
        div = parsed_html.body.find('div', attrs={'class':'entry-content'})
        # if the first paragraph starts with 'Q:' and the second with 'A:' than it is a Q & A style; 
        # take the second paragraph
        # otherwise take the first.
        parag = div.find_all("p")
        if(parag[0].text[0:3] == 'Q: ' and parag[1].text[0:3] == 'A: '):           
            return parag[1].text
        return parag[0].text
    except Exception as e:
        print(e)
    return result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.factcheck.afp.com

# %%
def get_factcheck_afp_title(url):
    result = "abstain"
    try:
        parsed_html = get_parsed_html(url)
        h3 = parsed_html.body.find('h3')
        return h3.text
    except Exception as e:
        print(e)
    return result
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.twitter.com

# %%
def extract_twitter_name(url):
    domain = "https://twitter.com/"
    sub = url[url.find(domain) + len(domain):]
    index = sub.find('/')
    if(index == -1):
        return sub
    else:
        return sub[:index]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Retrieving URLs of fact checking sites

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import time
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
fact_checking_sites = {
    "www.politifact.com" : get_poitifact_image_alt,
    "www.snopes.com": get_snopes_image_alt,
    "www.twitter.com":  extract_twitter_name,
    "www.factcheck.org": get_factcheck_first_paragraph,
    "factcheck.afp.com": get_factcheck_afp_title,
    "www.washingtonpost.com/news/fact-checker/": None,
    "www.realclearpolitics.com": None,
    "www.glennbeck.com": None,
}
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def sources_as_list(source, domain):
    urls = source[1:-1].split(',')
    u = []
    for url in urls:
        if domain in url:
            u.append(url)
    return u
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Initialize the new columns
for site in fact_checking_sites: 
      data[site] = None
    
data_size = data.shape[0]

# peek at the data
data.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>date</th>
#       <th>speaker</th>
#       <th>statement</th>
#       <th>sources</th>
#       <th>paragraph_based_content</th>
#       <th>fullText_based_content</th>
#       <th>label_fnn</th>
#       <th>label_numeric</th>
#       <th>www.politifact.com</th>
#       <th>www.snopes.com</th>
#       <th>www.twitter.com</th>
#       <th>www.factcheck.org</th>
#       <th>factcheck.afp.com</th>
#       <th>www.washingtonpost.com/news/fact-checker/</th>
#       <th>www.realclearpolitics.com</th>
#       <th>www.glennbeck.com</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3106</td>
#       <td>2011-01-25T06:00:00-05:00</td>
#       <td>Joe Wilkinson</td>
#       <td>A national organization says Georgia has one o...</td>
#       <td>['http://www.ajc.com/news/georgia-politics-ele...</td>
#       <td>['A coalition of government watchdog groups la...</td>
#       <td>A coalition of government watchdog groups last...</td>
#       <td>fake</td>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5655</td>
#       <td>2012-04-02T11:42:20-04:00</td>
#       <td>Rick Scott</td>
#       <td>Says Barack Obama's health care law "will be t...</td>
#       <td>['http://www.youtube.com/watch?v=TaC0mKApf9Q&amp;f...</td>
#       <td>['As Supreme Court justices embarked on three ...</td>
#       <td>As Supreme Court justices embarked on three da...</td>
#       <td>fake</td>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3506</td>
#       <td>2011-04-01T09:49:05-04:00</td>
#       <td>J.D. Alexander</td>
#       <td>Says the Southwest Florida Water Management Di...</td>
#       <td>['http://www.tampabay.com/news/politics/gubern...</td>
#       <td>["Here's a new one: The Senate budget committe...</td>
#       <td>Here's a new one: The Senate budget committee ...</td>
#       <td>fake</td>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#setup a dictionary for the results
fact_checking_sites_results = {
    "www.politifact.com" : [None] * data_size,
    "www.snopes.com": [None] * data_size,
    "www.twitter.com":  [None] * data_size,
    "www.factcheck.org": [None] * data_size,
    "factcheck.afp.com": [None] * data_size,
    "www.washingtonpost.com/news/fact-checker/": [None] * data_size,
    "www.realclearpolitics.com": [None] * data_size,
    "www.glennbeck.com": [None] * data_size,
}

#this output right now will look weird because of the structure of the dictionary
print(fact_checking_sites_results.items())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">dict_items([(&#39;www.politifact.com&#39;, [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, ...

# %% [markdown]
# ## Option 1 - Live data - Parse the sites and load the data

# %%
# #Iterate through the records
# #and looks through the sources for each fact-checking site

# for i, row in data.iterrows():
#     for site in fact_checking_sites: 
#         sources = sources_as_list(row["sources"], site)
#         if len(sources) != 0:
#             print("-{}".format(i), "id:", row["id"])
#             #print(sources)
#             labels = ""
#             for source in sources:
#                 handler = fact_checking_sites[site]
#                 if handler:
#                     #print("Handling: {} ++++++++++++++++++++++++++".format(site))
#                     source = str(source).strip()[1:-1]
#                     if(len(labels) > 0):
#                         labels += ", "+handler(str(source))
#                     else:
#                         labels += handler(str(source))
#                     #print("Result: {} ++++++++++++++++++++++++++".format(labels))
#                 else:
#                     if(len(labels) > 0):
#                         #print("Handling: {} ++++++++++++++++++++++++++".format(site))
#                         labels += ", "+ source
#                     else:
#                         labels += source
#                 #print("Result: {} ++++++++++++++++++++++++++".format(labels))
#             fact_checking_sites_results[site][i] =labels
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-1 id: 5655
# -4 id: 4776
# -6 id: 1415
# -6 id: 1415
# -7 id: 18318
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -7 id: 18318
# -13 id: 8377
# -15 id: 12989
# -19 id: 14911
# -19 id: 14911
# -22 id: 6427
# -26 id: 4072
# -28 id: 5779
# -36 id: 14163
# -37 id: 14196
# HTTP Error 404: Not Found
# -38 id: 3907
# -39 id: 6721
# -47 id: 17238
# -49 id: 2574
# -50 id: 14864
# -51 id: 1637
# -56 id: 7763
# -57 id: 10380
# -64 id: 13642
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -65 id: 11123
# -69 id: 13410
# -71 id: 15638
# -74 id: 5959
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -74 id: 5959
# -75 id: 13697
# -77 id: 17196
# -77 id: 17196
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -79 id: 7484
# -82 id: 5165
# -84 id: 13803
# -85 id: 6977
# -93 id: 7412
# -95 id: 16253
# -103 id: 6333
# -104 id: 13300
# -109 id: 8191
# -112 id: 9009
# -115 id: 13966
# -116 id: 13867
# -121 id: 12579
# -122 id: 13001
# -122 id: 13001
# -126 id: 15234
# -127 id: 16569
# -128 id: 10639
# -129 id: 4468
# -131 id: 4592
# -132 id: 10137
# -136 id: 4039
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -138 id: 7986
# -139 id: 17625
# -140 id: 15005
# -141 id: 15162
# -144 id: 8553
# -146 id: 16573
# -147 id: 15218
# -151 id: 11976
# -154 id: 8641
# -155 id: 16249
# -155 id: 16249
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -158 id: 14084
# -160 id: 7943
# -161 id: 14281
# -164 id: 11827
# -165 id: 4217
# -168 id: 15917
# -170 id: 12728
# -171 id: 10245
# -172 id: 11961
# -173 id: 4930
# -175 id: 9887
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -178 id: 15771
# -180 id: 4751
# -184 id: 17252
# -190 id: 16588
# -190 id: 16588
# -197 id: 6991
# -201 id: 1717
# -202 id: 16263
# -205 id: 15214
# -206 id: 10157
# -208 id: 17639
# -209 id: 17243
# -210 id: 16749
# -214 id: 4389
# -215 id: 6564
# -215 id: 6564
# -217 id: 14985
# -218 id: 13053
# -219 id: 16856
# -221 id: 11064
# -222 id: 7227
# -225 id: 4435
# -235 id: 15664
# -236 id: 17874
# -237 id: 16419
# -240 id: 8822
# -242 id: 9122
# -244 id: 6838
# -246 id: 15569
# -248 id: 14423
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -253 id: 318
# -256 id: 12777
# -258 id: 6302
# -260 id: 9002
# -264 id: 4104
# -266 id: 13360
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -272 id: 16775
# -273 id: 6478
# -273 id: 6478
# -274 id: 16140
# -278 id: 15867
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -279 id: 15439
# -281 id: 3327
# -282 id: 7057
# -284 id: 2663
# -287 id: 12444
# -290 id: 8300
# -296 id: 18174
# -299 id: 17076
# -302 id: 3152
# -303 id: 6126
# -307 id: 12245
# -309 id: 9001
# -311 id: 328
# HTTP Error 404: Not Found
# -318 id: 12019
# -319 id: 10229
# -328 id: 14103
# -329 id: 14886
# -329 id: 14886
# -335 id: 15229
# -336 id: 7628
# -340 id: 16319
# -342 id: 10525
# -343 id: 17504
# -343 id: 17504
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -344 id: 16181
# -346 id: 12163
# -347 id: 757
# -349 id: 11870
# -351 id: 4637
# -355 id: 7120
# -357 id: 7053
# -359 id: 8359
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -360 id: 5151
# -363 id: 12863
# -365 id: 16743
# -367 id: 11349
# -368 id: 12446
# -370 id: 12590
# -371 id: 11141
# -373 id: 12109
# -374 id: 10720
# -378 id: 9609
# -382 id: 8904
# -383 id: 4800
# -384 id: 12497
# -386 id: 13624
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -388 id: 15560
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -390 id: 9287
# -392 id: 16267
# -396 id: 17132
# -406 id: 11241
# -408 id: 17137
# -410 id: 17985
# -412 id: 3733
# -416 id: 16392
# -417 id: 1005
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -417 id: 1005
# HTTP Error 404: Not Found
# -421 id: 16650
# -421 id: 16650
# -422 id: 11719
# -427 id: 11668
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -427 id: 11668
# -431 id: 7354
# -432 id: 16875
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -434 id: 13142
# -435 id: 8502
# HTTP Error 404: Not Found
# -447 id: 6726
# -451 id: 9590
# -455 id: 14181
# -459 id: 8897
# -461 id: 10072
# -462 id: 14910
# -463 id: 11330
# -463 id: 11330
# -465 id: 13320
# -466 id: 15445
# -467 id: 1512
# -472 id: 16876
# -473 id: 15122
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -474 id: 17761
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -476 id: 6344
# -478 id: 10279
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -479 id: 676
# -482 id: 6440
# -487 id: 17814
# -488 id: 9113
# -490 id: 5263
# -493 id: 7363
# -496 id: 9005
# -500 id: 14367
# -505 id: 13169
# -508 id: 17005
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -511 id: 10080
# -514 id: 3190
# -519 id: 12396
# -525 id: 8598
# -530 id: 3513
# -531 id: 11406
# -537 id: 8678
# -541 id: 11612
# -546 id: 15918
# -550 id: 9341
# -551 id: 12038
# -551 id: 12038
# -551 id: 12038
# -553 id: 15358
# -555 id: 8845
# -558 id: 11242
# -562 id: 17446
# -563 id: 14881
# -564 id: 18314
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -565 id: 16131
# -568 id: 6297
# -570 id: 16874
# -576 id: 6056
# -577 id: 5108
# -580 id: 592
# -581 id: 18148
# -583 id: 12847
# -589 id: 12888
# -590 id: 9974
# -591 id: 10946
# -593 id: 13241
# -594 id: 13186
# -595 id: 10043
# -598 id: 11152
# -604 id: 11567
# -605 id: 7309
# -610 id: 6894
# -613 id: 8325
# -616 id: 13027
# -619 id: 15967
# -620 id: 9951
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -625 id: 705
# HTTP Error 404: Not Found
# -631 id: 1555
# -634 id: 16093
# -638 id: 10854
# -643 id: 7242
# -645 id: 7528
# -648 id: 10296
# -656 id: 1778
# -661 id: 6850
# -662 id: 14525
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -663 id: 16506
# -665 id: 13444
# -667 id: 8494
# -671 id: 10440
# -672 id: 15935
# -675 id: 12563
# -683 id: 6995
# -685 id: 12463
# -687 id: 12558
# -688 id: 16428
# -690 id: 15081
# -694 id: 11635
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -699 id: 8964
# -703 id: 6160
# -704 id: 6620
# -705 id: 9870
# -706 id: 6941
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -707 id: 13782
# -708 id: 1679
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -709 id: 8605
# -714 id: 13011
# -714 id: 13011
# -715 id: 4990
# -718 id: 7251
# -718 id: 7251
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -718 id: 7251
# -720 id: 6836
# -721 id: 5787
# -722 id: 11233
# -727 id: 17328
# -727 id: 17328
# &#39;NoneType&#39; object has no attribute &#39;find_all&#39;
# -728 id: 2259
# -728 id: 2259
# HTTP Error 404: Not Found
# -729 id: 7990
# -729 id: 7990
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -729 id: 7990
# -734 id: 12988
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -740 id: 16386
# -745 id: 6481
# -746 id: 11142
# -747 id: 13131
# -747 id: 13131
# -751 id: 9744
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -755 id: 16541
# -760 id: 15701
# -761 id: 4721
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -761 id: 4721
# -762 id: 10961
# -768 id: 5322
# -769 id: 5940
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -771 id: 10025
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -773 id: 8222
# -775 id: 9883
# -778 id: 7225
# -782 id: 13908
# -783 id: 17471
# -784 id: 8492
# -786 id: 10049
# -789 id: 15984
# &#39;NoneType&#39; object has no attribute &#39;find&#39;
# -791 id: 15145
# -793 id: 295
# HTTP Error 404: Not Found
# -796 id: 12408
# -798 id: 13105
# -801 id: 13019
# -803 id: 12020
# -804 id: 18198
# -806 id: 8711
# -808 id: 3633
# -810 id: 11810
# -811 id: 4086
# -812 id: 13015
# -816 id: 12823
# -817 id: 15373
# -825 id: 11403
# -828 id: 10867
# -830 id: 6812
# -831 id: 6102
# -835 id: 2536
# -838 id: 1666
# -839 id: 12326
# -841 id: 17276
# -847 id: 3707

# %% [markdown]
# ## Option 1 - Continued

# %%
# for site in fact_checking_sites:
#     data[site] = fact_checking_sites_results[site]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Option 2 - Load the data - saved to file earlier

# %%
## To keep this notebook consistent with the output in the chapters, and execute faster we downloaded the code
## and saved it locally as a csv. This allows the reader to run a apples-to-apples comparison on what they see
## and what is in the book. 

### ALTERNATIVE TO THE TWO CELL ABOVE, IF LOADING FROM THE FILE
apiResultsFile = pd.read_csv(API_RESULTS_dataFile, sep="|", encoding='utf-8', header=None)
apiResultsFile = apiResultsFile.where(cond=apiResultsFile.notna(), other=None)
apiResultsFile = apiResultsFile.where(cond=apiResultsFile.notnull(), other=None)

apiResultsFile.tail(3)

# process the data
for i, line in apiResultsFile.iterrows():
    #print(line[0], line[1], line[2])
    row = line[0]
    col = line[1].strip()
    data.at[row,col] = line[2].strip()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Peek at the data
data.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>date</th>
#       <th>speaker</th>
#       <th>statement</th>
#       <th>sources</th>
#       <th>paragraph_based_content</th>
#       <th>fullText_based_content</th>
#       <th>label_fnn</th>
#       <th>label_numeric</th>
#       <th>www.politifact.com</th>
#       <th>www.snopes.com</th>
#       <th>www.twitter.com</th>
#       <th>www.factcheck.org</th>
#       <th>factcheck.afp.com</th>
#       <th>www.washingtonpost.com/news/fact-checker/</th>
#       <th>www.realclearpolitics.com</th>
#       <th>www.glennbeck.com</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3106</td>
#       <td>2011-01-25T06:00:00-05:00</td>
#       <td>Joe Wilkinson</td>
#       <td>A national organization says Georgia has one o...</td>
#       <td>['http://www.ajc.com/news/georgia-politics-ele...</td>
#       <td>['A coalition of government watchdog groups la...</td>
#       <td>A coalition of government watchdog groups last...</td>
#       <td>fake</td>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5655</td>
#       <td>2012-04-02T11:42:20-04:00</td>
#       <td>Rick Scott</td>
#       <td>Says Barack Obama's health care law "will be t...</td>
#       <td>['http://www.youtube.com/watch?v=TaC0mKApf9Q&amp;f...</td>
#       <td>['As Supreme Court justices embarked on three ...</td>
#       <td>As Supreme Court justices embarked on three da...</td>
#       <td>fake</td>
#       <td>0</td>
#       <td>false, false, barely-true</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3506</td>
#       <td>2011-04-01T09:49:05-04:00</td>
#       <td>J.D. Alexander</td>
#       <td>Says the Southwest Florida Water Management Di...</td>
#       <td>['http://www.tampabay.com/news/politics/gubern...</td>
#       <td>["Here's a new one: The Senate budget committe...</td>
#       <td>Here's a new one: The Senate budget committee ...</td>
#       <td>fake</td>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Crowdsourcing

# %% [markdown]
# ### www.glennbeck.com

# %%
glenbeck_ratings = pd.read_csv(GB_dataFile);

for i, row in glenbeck_ratings.iterrows():
    data.loc[data["id"] == row["id"],["www.glennbeck.com"]] = row["www.glennbeck.com"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.realclearpolitics.com

# %%
rp_ratings = pd.read_csv(RP_dataFile);

for i, row in rp_ratings.iterrows():
    data.loc[data["id"] == row["id"],["www.realclearpolitics.com"]] = row["www.realclearpolitics.com"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.washingtonpost.com/news/fact-checker

# %%
wp_ratings = pd.read_csv(WP_dataFile);

for i, row in wp_ratings.iterrows():
    data.loc[data["id"] == row["id"],["www.washingtonpost.com/news/fact-checker/"]] = row["www.washingtonpost.com/news/fact-checker/"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.glennbeck.com

# %%
# gb_urls = {}
# counter = 0
# for i, row in data.iterrows():
#     poli = sources_as_list(row["sources"], "www.glennbeck.com")

#     if(len(poli) > 0):
#         gb_urls[i]= row["label_fnn"]
#     else:
#         gb_urls[i]= None
# data["www.glennbeck.com"] = gb_urls.values()
# data[data["www.glennbeck.com"].notnull()].shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.realclearpolitics.com

# %%
# gb_urls = {}
# counter = 0
# for i, row in data.iterrows():
#     poli = sources_as_list(row["sources"], "www.realclearpolitics.com")

#     if(len(poli) > 0):
#         gb_urls[i]= row["label_fnn"]
#     else:
#         gb_urls[i]= None
# data["www.realclearpolitics.com"] = gb_urls.values()
# data[data["www.realclearpolitics.com"].notnull()].shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ### www.washingtonpost.com/news/fact-checker/

# %%
# gb_urls = {}
# counter = 0
# for i, row in data.iterrows():
#     poli = sources_as_list(row["sources"], "www.washingtonpost.com/news/fact-checker/")

#     if(len(poli) > 0):
#         gb_urls[i]= row["label_fnn"]
#     else:
#         gb_urls[i]= None
# data["www.washingtonpost.com/news/fact-checker/"] = gb_urls.values()
# data[data["www.washingtonpost.com/news/fact-checker/"].notnull()].shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Learning the labels with Snorkel

# %% [markdown]
# ## Get only the subset of the data that has at least one label

# %%
data2 = data[data["www.politifact.com"].notnull() 
             | data["www.snopes.com"].notnull()
             | data["www.factcheck.org"].notnull()
             | data["factcheck.afp.com"].notnull()
             | data["www.realclearpolitics.com"].notnull()
             | data["www.glennbeck.com"].notnull()
             | data["www.washingtonpost.com/news/fact-checker/"].notnull()        
             | data["www.twitter.com"].notnull()]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#peek at it
data2.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>date</th>
#       <th>speaker</th>
#       <th>statement</th>
#       <th>sources</th>
#       <th>paragraph_based_content</th>
#       <th>fullText_based_content</th>
#       <th>label_fnn</th>
#       <th>label_numeric</th>
#       <th>www.politifact.com</th>
#       <th>www.snopes.com</th>
#       <th>www.twitter.com</th>
#       <th>www.factcheck.org</th>
#       <th>factcheck.afp.com</th>
#       <th>www.washingtonpost.com/news/fact-checker/</th>
#       <th>www.realclearpolitics.com</th>
#       <th>www.glennbeck.com</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>5655</td>
#       <td>2012-04-02T11:42:20-04:00</td>
#       <td>Rick Scott</td>
#       <td>Says Barack Obama's health care law "will be t...</td>
#       <td>['http://www.youtube.com/watch?v=TaC0mKApf9Q&amp;f...</td>
#       <td>['As Supreme Court justices embarked on three ...</td>
#       <td>As Supreme Court justices embarked on three da...</td>
#       <td>fake</td>
#       <td>0</td>
#       <td>false, false, barely-true</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4776</td>
#       <td>2011-11-13T07:30:00-05:00</td>
#       <td>Rodney Frelinghuysen</td>
#       <td>Says the Treasury Department "says 41 percent ...</td>
#       <td>['http://frelinghuysen.house.gov/index.cfm?sec...</td>
#       <td>['The millionaires’ tax proposal made its late...</td>
#       <td>The millionaires’ tax proposal made its latest...</td>
#       <td>fake</td>
#       <td>0</td>
#       <td>false, barely-true</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1415</td>
#       <td>2010-01-21T17:37:57-05:00</td>
#       <td>Chain email</td>
#       <td>The House health care bill provides for "free ...</td>
#       <td>['http://michaelconnelly.viviti.com/entries/ge...</td>
#       <td>["A chain e-mail written by former attorney Mi...</td>
#       <td>A chain e-mail written by former attorney Mich...</td>
#       <td>fake</td>
#       <td>0</td>
#       <td>half-true, false</td>
#       <td>None</td>
#       <td>None</td>
#       <td>A: Legal experts agree that requiring citizens...</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Labeling function

# %%
@labeling_function()
def label_snopes(row):
    label = row["www.snopes.com"]
    print(label)
    if label is not None:
        if ('real' in label):
            return REAL
        else: 
            return FAKE
    else: 
        return ABSTAIN
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
@labeling_function()
def label_wp(row):
    label = row["www.washingtonpost.com/news/fact-checker/"]
    if label is not None:
        if ('real' in label):
            return REAL
        else: 
            return FAKE
    else: 
        return ABSTAIN
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
@labeling_function()
def label_rp(row):
    label = row["www.realclearpolitics.com"]
    if label is not None:
        label = row["www.realclearpolitics.com"]
        #print(label)
        if ('real' in label):
            return REAL
        else: 
            return FAKE
    else: 
        return ABSTAIN
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
truth_o_meter = {
    "true": 4,
    "mostly-true": 3,
    "half-true": 2,
    "barely-true": 1,
    "mostly-false": -1,
    "false": -2,
    "pants-fire": -3    
}

@labeling_function()
def label_politifact(row):
    total_score = 0
    labels = row["www.politifact.com"]
    #print(labels)
    if(labels):
        labels = str(row["www.politifact.com"]).split(',')
        # The last label has the newline character
        if(len(labels) > 0):
            labels[-1] = labels[-1][:-2]
        for label in labels:
            #print(label)
            label = label.strip()
            if(label in truth_o_meter):
                total_score += truth_o_meter[label]                
    #print("score: {} ".format(total_score))          
    if(total_score > 0):
        return REAL
    if(total_score < 0): 
        return FAKE
    
    return ABSTAIN
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def factcheck_sentiment(row, columnName):
    label = str(row[columnName])
    score = 0
    if(label):
        claims = label[1:-1].split(',')
        for claim in claims:
            print(claim)
            sentiment = sid.polarity_scores(claim)
            print(sentiment)
            if(sentiment["neg"] > sentiment["pos"]):
                score -=1
            elif(sentiment["pos"] > sentiment["neg"]):
                score +=1
        if(score > 0):
            return REAL
        elif (score < 0):
            return FAKE
        else:
            return ABSTAIN
    return ABSTAIN
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
@labeling_function()
def factcheckqa_sentiment(row):
    return factcheck_sentiment(row, "www.factcheck.org")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
@labeling_function()
def factcheckafpqa_sentiment(row):
    return factcheck_sentiment(row, "factcheck.afp.com")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Transfer Learning from the liar dataset

# %%
# Load the Liar dataset
data3 = pd.read_csv(LIAR_dataFile)

#Clean up the NaN's
data3 = data3.where(cond=data3.notna(), other=None)
print("Count:", data3.count())

#Take a peek at the data to ensure all is correct
data3.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Count: id                         15052
# date                       15052
# speaker                    15052
# statement                  15052
# sources                    15052
# paragraph_based_content    15052
# fullText_based_content     15052
# label-liar                 15052
# dtype: int64
# Out[41]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>date</th>
#       <th>speaker</th>
#       <th>statement</th>
#       <th>sources</th>
#       <th>paragraph_based_content</th>
#       <th>fullText_based_content</th>
#       <th>label-liar</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18178</td>
#       <td>2020-03-18T13:26:42-04:00</td>
#       <td>Instagram posts</td>
#       <td>"COVID-19 started because we eat animals."</td>
#       <td>['https://www.cdc.gov/coronavirus/2019-ncov/ca...</td>
#       <td>['Vegan Instagram users are pinning the 2019 c...</td>
#       <td>Vegan Instagram users are pinning the 2019 cor...</td>
#       <td>barely-true</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3350</td>
#       <td>2011-03-04T09:12:59-05:00</td>
#       <td>Glenn Beck</td>
#       <td>Says Michelle Obama has 43 people on her staff...</td>
#       <td>['http://www.glennbeck.com/2011/02/25/while-wo...</td>
#       <td>['Glenn Beck rekindled a falsehood about the s...</td>
#       <td>Glenn Beck rekindled a falsehood about the siz...</td>
#       <td>pants-fire</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14343</td>
#       <td>2017-07-21T11:52:44-04:00</td>
#       <td>Mike Pence</td>
#       <td>Says President Donald Trump "has signed more l...</td>
#       <td>['https://nrf.com/events/retail-advocates-summ...</td>
#       <td>['Vice President Mike Pence says that when it ...</td>
#       <td>Vice President Mike Pence says that when it co...</td>
#       <td>half-true</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# check the unique labels
labels = data3["label-liar"].unique()

# peek at the labels to validate
print(labels)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[&#39;barely-true&#39; &#39;pants-fire&#39; &#39;half-true&#39; &#39;mostly-true&#39; &#39;true&#39; &#39;false&#39;]
# </div>

# %%
# true speakers
counts_true = collections.Counter(data3[(data3["label-liar"]=="mostly-true") | (data3["label-liar"]=="true")]["speaker"])
counts_true = dict(counts_true.most_common())

# false speakers
counts_false = collections.Counter(data3[(data3["label-liar"]=="false" )| (data3["label-liar"]=="pants-fire")]["speaker"])
counts_false = dict(counts_false.most_common())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
false_percent = {}

for k, v in counts_false.items():
    total = v
    if k in counts_true:
        total += counts_true[k]
    false_percent[k] = v/total
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
true_percent = {}

for k, v in counts_true.items():
    total = v
    if k in counts_false:
        total += counts_false[k]
    true_percent[k] = v/total
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
@labeling_function()
def speaker(row):
    speaker = row["speaker"]
    if(speaker in true_percent and true_percent[speaker] > 0.6):
        return REAL
    if(speaker in false_percent and false_percent[speaker] > 0.6):
        return FAKE
    return ABSTAIN
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Setup required to training the snorkel model

# %%
#Split the data in a 80 - 20 % ratio between train and test
data_size = data.shape[0]
train_data_size = int(data_size*0.8)

print("Data shape",data.shape)
print("Training data size",train_data_size)

data = data.sample(frac=1, random_state=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Data shape (15212, 17)
# Training data size 12169
# </div>

# %%
# data[['www.twitter.com','www.politifact.com','www.snopes.com','www.factcheck.org','factcheck.afp.com','www.washingtonpost.com/news/fact-checker/','www.realclearpolitics.com','www.glennbeck.com']] = data[['www.twitter.com','www.politifact.com','www.snopes.com','www.factcheck.org','factcheck.afp.com','www.washingtonpost.com/news/fact-checker/','www.realclearpolitics.com','www.glennbeck.com']].astype(str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Generating agreement from weak classifiers

# %%
lfs = [
        label_rp,
        label_wp, 
        label_snopes,
        label_politifact,
        factcheckqa_sentiment,
        factcheckafpqa_sentiment,
        speaker
      ]

#need to convert panda DF's to Spark DF's and then to RDDs
rdd_data = spark.createDataFrame(data).rdd

# Split the data in an 80-20 ratio for train and test
df_train = data[:train_data_size]
df_train = df_train.where((pd.notnull(df_train)), None)

df_valid = data[train_data_size:]
df_valid = df_valid.where((pd.notnull(df_valid)), None)

# invoke Snorkel
applier = SparkLFApplier(lfs=lfs)
L_train = applier.apply(rdd_data)
LFAnalysis(L=L_train, lfs=lfs).lf_summary()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[49]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>j</th>
#       <th>Polarity</th>
#       <th>Coverage</th>
#       <th>Overlaps</th>
#       <th>Conflicts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>label_rp</th>
#       <td>0</td>
#       <td>[0, 1]</td>
#       <td>0.007889</td>
#       <td>0.006574</td>
#       <td>0.001906</td>
#     </tr>
#     <tr>
#       <th>label_wp</th>
#       <td>1</td>
#       <td>[0, 1]</td>
#       <td>0.010387</td>
#       <td>0.009400</td>
#       <td>0.003353</td>
#     </tr>
#     <tr>
#       <th>label_snopes</th>
#       <td>2</td>
#       <td>[0]</td>
#       <td>0.027807</td>
#       <td>0.026887</td>
#       <td>0.003024</td>
#     </tr>
#     <tr>
#       <th>label_politifact</th>
#       <td>3</td>
#       <td>[0, 1]</td>
#       <td>0.126413</td>
#       <td>0.093479</td>
#       <td>0.037142</td>
#     </tr>
#     <tr>
#       <th>factcheckqa_sentiment</th>
#       <td>4</td>
#       <td>[0, 1]</td>
#       <td>0.020379</td>
#       <td>0.018998</td>
#       <td>0.009663</td>
#     </tr>
#     <tr>
#       <th>factcheckafpqa_sentiment</th>
#       <td>5</td>
#       <td>[0, 1]</td>
#       <td>0.000986</td>
#       <td>0.000986</td>
#       <td>0.000592</td>
#     </tr>
#     <tr>
#       <th>speaker</th>
#       <td>6</td>
#       <td>[0, 1]</td>
#       <td>0.717920</td>
#       <td>0.134236</td>
#       <td>0.044833</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Clean up datatypes for spark runtime

# %%
# # Training dataset
# df_train[['www.twitter.com','www.politifact.com','www.snopes.com','www.factcheck.org','factcheck.afp.com','www.washingtonpost.com/news/fact-checker/','www.realclearpolitics.com','www.glennbeck.com']] = df_train[['www.twitter.com','www.politifact.com','www.snopes.com','www.factcheck.org','factcheck.afp.com','www.washingtonpost.com/news/fact-checker/','www.realclearpolitics.com','www.glennbeck.com']].astype(str)

# # Validation dataset
# df_valid[['www.twitter.com','www.politifact.com','www.snopes.com','www.factcheck.org','factcheck.afp.com','www.washingtonpost.com/news/fact-checker/','www.realclearpolitics.com','www.glennbeck.com']] = df_valid[['www.twitter.com','www.politifact.com','www.snopes.com','www.factcheck.org','factcheck.afp.com','www.washingtonpost.com/news/fact-checker/','www.realclearpolitics.com','www.glennbeck.com']].astype(str)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Convert Pandas dataframe to Spark dataframe

# %%
# Need to convert panda DF's to Spark DF's and then to RDDs

# Training dataset conversion
rdd_train = spark.createDataFrame(df_train).rdd

# Validation dataset conversion
rdd_valid = spark.createDataFrame(df_valid).rdd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
majority_model = MajorityLabelVoter()
preds_train_majority = majority_model.predict(L=L_train)
L_valid = applier.apply(rdd_valid)

Y_valid = df_valid["label_numeric"].values
LFAnalysis(L_valid, lfs).lf_summary(Y_valid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn(&#34;Pass {} as keyword args. From version 0.25 &#34;
# Out[52]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>j</th>
#       <th>Polarity</th>
#       <th>Coverage</th>
#       <th>Overlaps</th>
#       <th>Conflicts</th>
#       <th>Correct</th>
#       <th>Incorrect</th>
#       <th>Emp. Acc.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>label_rp</th>
#       <td>0</td>
#       <td>[0, 1]</td>
#       <td>0.007558</td>
#       <td>0.005587</td>
#       <td>0.001972</td>
#       <td>23</td>
#       <td>0</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>label_wp</th>
#       <td>1</td>
#       <td>[0, 1]</td>
#       <td>0.012488</td>
#       <td>0.012159</td>
#       <td>0.004601</td>
#       <td>38</td>
#       <td>0</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>label_snopes</th>
#       <td>2</td>
#       <td>[0]</td>
#       <td>0.028262</td>
#       <td>0.026947</td>
#       <td>0.002629</td>
#       <td>77</td>
#       <td>9</td>
#       <td>0.895349</td>
#     </tr>
#     <tr>
#       <th>label_politifact</th>
#       <td>3</td>
#       <td>[0, 1]</td>
#       <td>0.120933</td>
#       <td>0.086756</td>
#       <td>0.033520</td>
#       <td>224</td>
#       <td>144</td>
#       <td>0.608696</td>
#     </tr>
#     <tr>
#       <th>factcheckqa_sentiment</th>
#       <td>4</td>
#       <td>[0, 1]</td>
#       <td>0.019717</td>
#       <td>0.017746</td>
#       <td>0.009201</td>
#       <td>37</td>
#       <td>23</td>
#       <td>0.616667</td>
#     </tr>
#     <tr>
#       <th>factcheckafpqa_sentiment</th>
#       <td>5</td>
#       <td>[0, 1]</td>
#       <td>0.001643</td>
#       <td>0.001643</td>
#       <td>0.000986</td>
#       <td>2</td>
#       <td>3</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <th>speaker</th>
#       <td>6</td>
#       <td>[0, 1]</td>
#       <td>0.704568</td>
#       <td>0.129149</td>
#       <td>0.041735</td>
#       <td>1645</td>
#       <td>499</td>
#       <td>0.767257</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Training the model

# %%
label_model = LabelModel()
label_model.fit(L_train=L_train, n_epochs=200, log_freq=100, seed=42)
preds_train_label = label_model.predict(L=L_train)
preds_valid_label = label_model.predict(L=L_valid)
L_valid = applier.apply(rdd_valid)

Y_valid = df_valid["label_numeric"].values
LFAnalysis(L_valid, lfs).lf_summary(Y_valid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/python/lib/python3.8/site-packages/sklearn/utils/validation.py:67: FutureWarning: Pass labels=[-1  0  1] as keyword args. From version 0.25 passing these as positional arguments will result in an error
#   warnings.warn(&#34;Pass {} as keyword args. From version 0.25 &#34;
# Out[53]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>j</th>
#       <th>Polarity</th>
#       <th>Coverage</th>
#       <th>Overlaps</th>
#       <th>Conflicts</th>
#       <th>Correct</th>
#       <th>Incorrect</th>
#       <th>Emp. Acc.</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>label_rp</th>
#       <td>0</td>
#       <td>[0, 1]</td>
#       <td>0.007558</td>
#       <td>0.005587</td>
#       <td>0.001972</td>
#       <td>23</td>
#       <td>0</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>label_wp</th>
#       <td>1</td>
#       <td>[0, 1]</td>
#       <td>0.012488</td>
#       <td>0.012159</td>
#       <td>0.004601</td>
#       <td>38</td>
#       <td>0</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <th>label_snopes</th>
#       <td>2</td>
#       <td>[0]</td>
#       <td>0.028262</td>
#       <td>0.026947</td>
#       <td>0.002629</td>
#       <td>77</td>
#       <td>9</td>
#       <td>0.895349</td>
#     </tr>
#     <tr>
#       <th>label_politifact</th>
#       <td>3</td>
#       <td>[0, 1]</td>
#       <td>0.120933</td>
#       <td>0.086756</td>
#       <td>0.033520</td>
#       <td>224</td>
#       <td>144</td>
#       <td>0.608696</td>
#     </tr>
#     <tr>
#       <th>factcheckqa_sentiment</th>
#       <td>4</td>
#       <td>[0, 1]</td>
#       <td>0.019717</td>
#       <td>0.017746</td>
#       <td>0.009201</td>
#       <td>37</td>
#       <td>23</td>
#       <td>0.616667</td>
#     </tr>
#     <tr>
#       <th>factcheckafpqa_sentiment</th>
#       <td>5</td>
#       <td>[0, 1]</td>
#       <td>0.001643</td>
#       <td>0.001643</td>
#       <td>0.000986</td>
#       <td>2</td>
#       <td>3</td>
#       <td>0.400000</td>
#     </tr>
#     <tr>
#       <th>speaker</th>
#       <td>6</td>
#       <td>[0, 1]</td>
#       <td>0.704568</td>
#       <td>0.129149</td>
#       <td>0.041735</td>
#       <td>1645</td>
#       <td>499</td>
#       <td>0.767257</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Check model quality

# %%
f1_micro = label_model.score(L_valid, Y_valid, metrics=["f1_micro"])
accuracy = label_model.score(L_valid, Y_valid, metrics=["accuracy"])
recall = label_model.score(L_valid, Y_valid, metrics=["recall"])
precision = label_model.score(L_valid, Y_valid, metrics=["precision"])

print("{}\n{}\n{}\n{}".format(f1_micro, accuracy, recall, precision))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">WARNING:root:Metrics calculated over data points with non-abstain labels only
# WARNING:root:Metrics calculated over data points with non-abstain labels only
# WARNING:root:Metrics calculated over data points with non-abstain labels only
# WARNING:root:Metrics calculated over data points with non-abstain labels only
# {&#39;f1_micro&#39;: 0.7512109202994276}
# {&#39;accuracy&#39;: 0.7512109202994276}
# {&#39;recall&#39;: 0.7953941541186891}
# {&#39;precision&#39;: 0.7288961038961039}
# </div>

# %% [markdown]
# ## Clean up

# %%
snorkel_predictions = np.concatenate((preds_train_label,preds_valid_label))
snorkel_predictions.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[55]: (18255,)</div>

# %%
#data["snorkel_labels"] = snorkel_predictions

# peek at the data to validate
data3.head(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[56]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>date</th>
#       <th>speaker</th>
#       <th>statement</th>
#       <th>sources</th>
#       <th>paragraph_based_content</th>
#       <th>fullText_based_content</th>
#       <th>label-liar</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18178</td>
#       <td>2020-03-18T13:26:42-04:00</td>
#       <td>Instagram posts</td>
#       <td>"COVID-19 started because we eat animals."</td>
#       <td>['https://www.cdc.gov/coronavirus/2019-ncov/ca...</td>
#       <td>['Vegan Instagram users are pinning the 2019 c...</td>
#       <td>Vegan Instagram users are pinning the 2019 cor...</td>
#       <td>barely-true</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3350</td>
#       <td>2011-03-04T09:12:59-05:00</td>
#       <td>Glenn Beck</td>
#       <td>Says Michelle Obama has 43 people on her staff...</td>
#       <td>['http://www.glennbeck.com/2011/02/25/while-wo...</td>
#       <td>['Glenn Beck rekindled a falsehood about the s...</td>
#       <td>Glenn Beck rekindled a falsehood about the siz...</td>
#       <td>pants-fire</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>14343</td>
#       <td>2017-07-21T11:52:44-04:00</td>
#       <td>Mike Pence</td>
#       <td>Says President Donald Trump "has signed more l...</td>
#       <td>['https://nrf.com/events/retail-advocates-summ...</td>
#       <td>['Vice President Mike Pence says that when it ...</td>
#       <td>Vice President Mike Pence says that when it co...</td>
#       <td>half-true</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# save to disk
data.to_csv("/dbfs/FileStore/test/data_nlp.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
