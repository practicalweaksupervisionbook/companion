# %%
import fire
import json
import os
import numpy as np
import tensorflow as tf

import model
import sample
import encoder

from snorkel.augmentation import transformation_function

# %% [markdown]
# ### Data Augmentation by predicting the next sentence with GPT-2

# %% [markdown]
# #create a python 3.7 environment
# conda create -n GPT2 python=3.7
#
# #activate the environment
# conda activate GPT2
#
# download GPT2
# git clone https://github.com/openai/gpt-2.git
#
# install the requirements, as presented in the repository
# There are no conda packages for fire and regex, resorting to pip
# for the installation
# pip install -r requirements.txt
#
# '''
# If you start the program, and you start seeing missing pacakges, you might
# want to install them one by one.
# I had to do so for tensorflow
# If you don't have a GPU, you can install just the 'tensorflow' package.
# '''
# pip install tensorflow-gpu==1.12.0
#
# '''
# Download one of the pretrained models. To strike a balance between speed of
# execution and accuracy, we will use the 355M model. The other models are: 124M, 355M, 774M and 1558M.
# '''
# python download_model.py 355M

# %% [markdown]
# Substitute the "GPT_2_Models" with the path to the gpt-2\modes folder (code\companion\ch02_labeling_and_augmentation\gpt-2\models).

# %%
def interact_model(
    raw_text,
    model_name='774M',
    seed=None,
    nsamples=1,
    batch_size=1,
    length= None,
    temperature=1,
    top_k=40,
    top_p=1,
    models_dir=r"GPT_2_Models",
):
    enc = encoder.get_encoder(model_name, models_dir)
    hparams = model.default_hparams()
    with open(os.path.join(models_dir, model_name, 'hparams.json')) as f:
        hparams.override_from_dict(json.load(f))

    if length is None:
        length = hparams.n_ctx // 2

    with tf.Session(graph=tf.Graph()) as sess:
        context = tf.placeholder(tf.int32, [batch_size, None])
        np.random.seed(seed)
        tf.set_random_seed(seed)
        output = sample.sample_sequence(
            hparams=hparams, length=length,
            context=context,
            batch_size=batch_size,
            temperature=temperature, top_k=top_k, top_p=top_p
        )

        saver = tf.train.Saver()
        ckpt = tf.train.latest_checkpoint(os.path.join(models_dir, model_name))
        saver.restore(sess, ckpt)

        context_tokens = enc.encode(raw_text)
        all_text = []
        for _ in range(nsamples // batch_size):
            out = sess.run(output, feed_dict={
                context: [context_tokens for _ in range(batch_size)]
            })[:, len(context_tokens):]
            for i in range(batch_size):
                text = enc.decode(out[i])
                all_text.append(text)
        return ''.join(all_text)

# %%
t = interact_model("Something did not feel right, since the first day.", length=50)
t
# Out:
# WARNING:tensorflow:From C:\Users\sefilipi\Documents\books\snorkel\code\companion\ch02_labeling_and_augmentation\gpt-2\src\sample.py:51: The name tf.AUTO_REUSE is deprecated. Please use tf.compat.v1.AUTO_REUSE instead.
#
# WARNING:tensorflow:From C:\Users\sefilipi\Documents\books\snorkel\code\companion\ch02_labeling_and_augmentation\gpt-2\src\model.py:148: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From C:\Users\sefilipi\Documents\books\snorkel\code\companion\ch02_labeling_and_augmentation\gpt-2\src\model.py:152: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:From C:\Users\sefilipi\Documents\books\snorkel\code\companion\ch02_labeling_and_augmentation\gpt-2\src\model.py:36: The name tf.rsqrt is deprecated. Please use tf.math.rsqrt instead.
#
# WARNING:tensorflow:From C:\Users\sefilipi\Documents\books\snorkel\code\companion\ch02_labeling_and_augmentation\gpt-2\src\sample.py:64: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:From C:\Users\sefilipi\Documents\books\snorkel\code\companion\ch02_labeling_and_augmentation\gpt-2\src\sample.py:16: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\sefilipi\Documents\books\snorkel\code\companion\ch02_labeling_and_augmentation\gpt-2\src\sample.py:67: multinomial (from tensorflow.python.ops.random_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.random.categorical` instead.
# INFO:tensorflow:Restoring parameters from C:\Users\sefilipi\Documents\books\snorkel\code\companion\ch02_labeling_and_augmentation\gpt-2\models\774M\model.ckpt
# " So I decided to go with my wife. We left home together just as we went to buy new clothes, my wife was the first on the drive, she didn't go too fast.\n\nAfter that I sat in the car and did everything"

# %%
@transformation_function()
def predict_next(x):
    review = x["review_text"]
    # extract the first sentence
    period_index = review.find('.')
    first_sentence = review[:period_index+1]
    #predict and get full sentences only.
    predicted = interact_model(review, length=50)
    last_period = predicted.rfind('.')
    sentence = first_sentence+" "+predicted[:last_period+1]
    x["review_text"] = sentence
    return x

# %%
k = predict_next(df[df.product_name == 'Honest Illusions: Books: Nora Roberts'].iloc[0])
k
# Out:
# PREDICT_NEXT
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     I simply adore this book and it's what made me...
# reviewer                                  L. Cortes "Book Junkie"
# Name: 2054, dtype: object
# INFO:tensorflow:Restoring parameters from C:\Users\sefilipi\Documents\books\snorkel\chapter 2\Data\gpt-2\models\774M\model.ckpt
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     I simply adore this book and it's what made me...
# reviewer                                  L. Cortes "Book Junkie"
# Name: 2054, dtype: object

# %% [markdown]
# ### Data Augmentation through translation

# %%
import os, requests, uuid, json
import spacy
nlp = spacy.load('en')

# %% [markdown]
# Substitute the following "KEY", "ENDPOINT", "REGION" placeholders with the values found in your deployed instance, as illustrated in Figure 2-4.

# %%
resource_key = '<KEY>'
endpoint = '<ENDPOINT>'
region = '<REGION>'

# %%
def translate(text, language):
    headers = {
    'Ocp-Apim-Subscription-Key': resource_key,
    "Ocp-Apim-Subscription-Region" : region,
    'Content-type': 'application/json',
    'X-ClientTraceId': str(uuid.uuid4())
    }

    body = [{'text' : text}]
    response = requests.post(
        endpoint+"/translate?api-version=3.0&to="+language,
        headers=headers, json=body)
    translation = response.json()[0]["translations"][0]["text"]
    return translation


@transformation_function()
def augment_by_translation(x):
    text = x["review_text"]
    french = translate(text, "fr")
    english = translate(french, "en")
    score = nlp(text).similarity(nlp(english))
    if(score < 1.0):
        x["review_text"] = english
    else:
        x["review_text"] = "DUPLICATE"
    return x

# %%
k = augment_by_translation(df[df.product_name == 'Honest Illusions: Books: Nora Roberts'].iloc[0])
k
# Out:
# AUGMENT_BY_TRANSLATION
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     I simply adore this book and it's what made me...
# reviewer                                  L. Cortes "Book Junkie"
# Name: 2054, dtype: object
# C:\Users\sefilipi\AppData\Local\Continuum\anaconda3\envs\GPT2\lib\site-packages\ipykernel_launcher.py:26: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
# AUGMENT_BY_TRANSLATION RETURN
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     I love this book and that's what made me come ...
# reviewer                                  L. Cortes "Book Junkie"
# Name: 2054, dtype: object

# %% [markdown]
# ### Augment by removing adverbs

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sefilipi\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
tags_to_remove = ["RB", "RBR", "RBS"]
@transformation_function()
def remove_adverbs(x):
    tokens = nltk.word_tokenize(x["review_text"])
    pos_tags = nltk.pos_tag(tokens)
    new_text = " ".join([x[0] for x in pos_tags if x[1] not in tags_to_remove]).replace(" .", ".")
    if(len(new_text) != len(tokens)):
        x["review_text"] = new_text
    else:
        x["review_text"] = "DUPLICATE"
    return x

# %%
remove_adverbs(df[df.product_name == 'Honest Illusions: Books: Nora Roberts'].iloc[0])
# Out:
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     I adore this book and it 's what made me go ou...
# reviewer                                  L. Cortes "Book Junkie"
# Name: 2054, dtype: object

# %% [markdown]
# ### Remove Adverbs using SpacyPreprocessor

# %%
from snorkel.preprocess.nlp import SpacyPreprocessor

spacy = SpacyPreprocessor(text_field="review_text", doc_field="doc", language="en")

# %%
df[df.product_name == 'Honest Illusions: Books: Nora Roberts'].iloc[0]["review_text"]
# Out:
# "I simply adore this book and it's what made me go out to buy every other Nora Roberts novel.  It just amazes me the chemistry between Luke and Roxanne.  Everytime I read it I can't get over the excitement and the smile it brings to me as they barb back and forth.  It's just an amazing story over the course of growing up together and how it all develops.  Roxanne is smart and sassy and Luke is just too cool.  This romantic duo shines and no one else compares to them yet for me.  My very favorite romance"

# %%
@transformation_function(pre=[spacy])
def spacy_remove_adverbs(x):
    words_no_adverbs = [token for i, token in enumerate(x.doc) 
                        if token.pos_ != "ADV"]
    new_sentence = " ".join([x.text for x in words_no_adverbs])
    if(len(words_no_adverbs) != len(x["review_text"])):
        x["review_text"] = new_sentence.replace(" .  ", ". ")
    else:
        x["review_text"]= "DUPLICATE"
    return x

# %%
spacy_remove_adverbs(df[df.product_name == 'Honest Illusions: Books: Nora Roberts'].iloc[0])
# Out:
# SPACY_REMOVE_ADVERBS
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     I simply adore this book and it's what made me...
# reviewer                                  L. Cortes "Book Junkie"
# Name: 2054, dtype: object
# SPACY_REMOVE_ADVERBS RETURN
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     I adore this book and it 's what made me go ou...
# reviewer                                  L. Cortes "Book Junkie"
# Name: 2054, dtype: object

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import xml.etree.ElementTree as et 

xtree = et.parse(r"C:\Users\sefilipi\Documents\books\snorkel\chapter 2\Data\book.unlabeled")
xroot = xtree.getroot()
df_cols = ["product_name", "review_text", "reviewer"]
records = []

for node in xroot: 
    text = node.find("review_text").text.replace('\n', '')
    title = node.find("product_name").text.replace('\n', '')
    reviewer = node.find("reviewer").text.replace('\n', '')
    records.append({"review_text": text, "product_name": title, "reviewer": reviewer})

df = pd.DataFrame(records, columns = df_cols)
df.head(30)
# Out:
#                                          product_name  \
# 0   Manual pedi�trico para los due�os del nuevo be...
# 1                Child of God: Books: Cormac Mccarthy
# 2                Child of God: Books: Cormac Mccarthy
# 3                Child of God: Books: Cormac Mccarthy
# 4                Child of God: Books: Cormac Mccarthy
# 5                Child of God: Books: Cormac Mccarthy
# 6                Child of God: Books: Cormac Mccarthy
# 7                Child of God: Books: Cormac Mccarthy
# 8                Child of God: Books: Cormac Mccarthy
# 9   Building, Buying and Operating a Boarding Kenn...
# 10         The Protector's War: Books: S. M. Stirling
# 11         The Protector's War: Books: S. M. Stirling
# 12         The Protector's War: Books: S. M. Stirling
# 13         The Protector's War: Books: S. M. Stirling
# 14         The Protector's War: Books: S. M. Stirling
# 15         The Protector's War: Books: S. M. Stirling
# 16         The Protector's War: Books: S. M. Stirling
# 17         The Protector's War: Books: S. M. Stirling
# 18  American Colonies: The Settling of North Ameri...
# 19  American Colonies: The Settling of North Ameri...
# 20  American Colonies: The Settling of North Ameri...
# 21  American Colonies: The Settling of North Ameri...
# 22  American Colonies: The Settling of North Ameri...
# 23  American Colonies: The Settling of North Ameri...
# 24  American Colonies: The Settling of North Ameri...
# 25  American Colonies: The Settling of North Ameri...
# 26  American Colonies: The Settling of North Ameri...
# 27  Secret Life of Bees, The (Essential Edition): ...
# 28  Secret Life of Bees, The (Essential Edition): ...
# 29  Secret Life of Bees, The (Essential Edition): ...
#
#                                           review_text  \
# 0   This all-Spanish handbook for parents with new...
# 1   McCarthy's writing and portrayal of Lester Bal...
# 2   Do you giggle uncontrollably when poking corps...
# 3   I was initiated into the world of Cormac McCar...
# 4   I cannot speak to the literary points in the n...
# 5   There is no denying the strain of Faulkner tha...
# 6   I have read sevral of McCarthy's other novels....
# 7   This is a gripping novel that probes the bread...
# 8   If you're considering buying the Peter Smith "...
# 9   What I didn't realise when I ordered this is t...
# 10  "Ha ha ha hah ha hah!"  That's Stirling laughi...
# 11  The Protector's War (2005) is the second Alter...
# 12  I loved Stirling's "Islands in the Sea of Time...
# 13  It completely sucked. Very long with nothing t...
# 14  I found that everytime I started getting to li...
# 15  Yet another fine effort from Stirling.  The fi...
# 16  Mr. Stirling has succeded again.  Protector's ...
# 17  While I enjoyed most of Dies the Fire, by the ...
# 18  Read this book!  I never thought a history boo...
# 19  Many reviewers have commented that Taylor's "A...
# 20  The reviews of this book are greater entertain...
# 21  Has a pretentiousness to it that is sometimes ...
# 22  I found this book well researched and full of ...
# 23  We all learned the basics of colonial history ...
# 24  Traditionally, coverage of "colonial America" ...
# 25  Books like this are regrettably--but understan...
# 26  Taylor provides an extensive - 526 pages inclu...
# 27  The above is my favorite book and SLB conjured...
# 28  The story is quite compelling as it interweave...
# 29  I read this book 2 years ago, and I must say t...
#
#                                              reviewer
# 0                                 Midwest Book Review
# 1                                       Brian Asquith
# 2                                        Bruce Miller
# 3                Christopher Davis "Christopher E.D."
# 4                                        Alex Johnson
# 5                                               Steve
# 6                                 William J. Fickling
# 7                                        Robert Ortiz
# 8                                      Allan MacInnis
# 9                                   Jennifer Robinson
# 10                                      Thomas Newell
# 11                                   Arthur W. Jordin
# 12                           R. Morris "M   R MORRIS"
# 13                                     David A. Teich
# 14                                        Thomas Bond
# 15                                      D. C. Caughey
# 16                                  Michael D. Willis
# 17  Herbert O. Rich "Instructor of Chen Style Taij...
# 18                                Jennifer Berkemeier
# 19                                        Joseph Ryan
# 20                                          R. Jessen
# 21                          Honeyspidey "Honeyspidey"
# 22                                       Joan Gardner
# 23                                 Rodolphe Boulanger
# 24                                        Mark Klobas
# 25                                         Bill Perez
# 26                                            C. Ryan
# 27                  A. R. Archambault "photogirl1972"
# 28                                 Juana M. De Pelaez
# 29                             Briana Seigal "smiles"

# %%
df.product_name.unique()
# Out:
# array(['Manual pedi�trico para los due�os del nuevo beb�: Books: Graciela Esquivel-Aguilar,Horst D. Weinburg',
#        'Child of God: Books: Cormac Mccarthy',
#        'Building, Buying and Operating a Boarding Kennel: Books: James Krack',
#        "The Protector's War: Books: S. M. Stirling",
#        'American Colonies: The Settling of North America (The Penguin History of the United States, Volume1) (Hist of the USA): Books: Alan Taylor',
#        'Secret Life of Bees, The (Essential Edition): (Penguin Essential Edition): Books: Sue  Kidd',
#        "Red Star Over Hollywood: The Film Colony's Long Romance with the Left: Books: Ronald Radosh",
#        'The Corporate University Handbook: Designing, Managing, and Growing a Successful Program: Books: Mark Allen',
#        'Turn Up the Heat with G. Garvin: Books: Gerry Garvin',
#        'Rescue: Books: Nicholas Sparks',
#        'Secret Life of Bees: CD: Books: Sue Monk Kidd',
#        'The Messenger: Books: Daniel Silva',
#        'Making Things Public: Atmospheres of Democracy: Books: Bruno Latour,Peter Weibel',
#        'The Culture of Education: Books: Jerome Bruner',
#        'Heartburn (Virago Modern Classics): Books: Nora Ephron',
#        'The Best Democracy Money Can Buy: An Investigative Reporter Exposes the Truth about Globalization, Corporate Cons, and High Finance Fraudsters: Books: Greg Palast',
#        'Running with Scissors: A Memoir: Books: Augusten Burroughs',
#        'South Beach Sizzle (Simon Romantic Comedies): Books: Suzanne Weyn,Diana Gonzalez',
#        'Vitamin D: New Perspectives in Drawing: Books: Emma Dexter',
#        'Freedom from Fear: The American People in Depression and War, 1929-1945 (Oxford History of the United States): Books: David M. Kennedy',
#        'Management Challenges for the 21st Century: Books: Peter Ferdinand Drucker,Mark Blum',
#        'Seven Choices: Finding Daylight After Loss Shatters Your World: Books: Elizabeth Harper Neeld',
#        'Scholarship Handbook 2006 (College Board Scholarship Handbook): Books: The College Board',
#        "The Only Investment Guide You'll Ever Need: Books: Andrew Tobias",
#        'The House On Hope Street: Books: Danielle Steel',
#        'Escoffier: The Complete Guide to the Art of Modern Cookery: Books: H. L. Cracknell,R. J. Kaufmann',
#        'A Crack in the Edge of the World: America and the Great California Earthquake of 1906: Books: Simon Winchester',
#        "Bears' Guide to College Degrees by Mail   Internet: 100 Accredited Schools That Offer Bachelor'S, Master'S, Doctorates, and Law Degrees by Distance Learning (College Degrees By Mail and Internet): Books: John Bear,Mariah Bear,Mariah P. Bear",
#        'And the Band Played on: Politics, People, And the AIDS Epidemic: Books: Randy Shilts',
#        'Microeconomics: Books: David Besanko,Ronald R. Braeutigam',
#        'A History of the American People: Books: Paul Johnson',
#        'Birthright: Books: Nora Roberts',
#        'The Rifles (Seven Dreams): Books: William Vollmann',
#        'Lincoln the Unknown: Books: Dale Carnegie',
#        'Churchill on Leadership: Executive Success in the Face of Adversity: Books: Steven F. Hayward',
#        'The Law Of Torts: Examples And Explanations (Examples   Explanations): Books: Joseph W. Glannon',
#        'Great Expectations (Dover Thrift Editions): Books: Charles Dickens',
#        'Cloud Mountain: Books: Aimee E. Liu',
#        'Elizabeth 1 CEO: Books: Axelrod',
#        'The Force of Reason: Books: Oriana Fallaci',
#        'Now, Discover Your Strengths: Books: Marcus Buckingham,Donald O. Clifton',
#        "Valerie   Walter's Best Books for Children 2nd Ed: A Lively, Opinionated Guide (Valerie   Walter's Best Books for Children: A Lively,): Books: Walter M. Mayes,Valerie Lewis",
#        "Eve's Seed: Biology, the Sexes, and the Course of History: Books: Robert S. McElvaine",
#        'The American Century Cookbook: Books: Jean Anderson',
#        'Judge   Jury: Books: James Patterson,Andrew Gross,Joe Mantegna',
#        'The Watcher and Other Stories: Books: Italo Calvino',
#        'Painted House: Books: John Grisham',
#        'Strip Tease (Price-Less Audios): Books: Carl Hiaasen,Edward Asner',
#        "Cooking Outside the Pizza Box: Easy Recipes for Today's College Student: Books: Jean Patterson,Danae Campbell",
#        'How the Mind Works: Books: Steven Pinker',
#        'As a Man Thinketh: Books: James Allen',
#        'The Far Side Gallery: Books: Gary Larson',
#        'Sphere: Books: Michael Crichton',
#        'Legal Writing in Plain English: A Text With Exercises: Books: Bryan A. Garner',
#        "Summer's End: Books: Danielle Steel",
#        'Tearing Down the Walls: How Sandy Weill Fought His Way to the Top of the Financial World. . .and Then Nearly Lost It All (Wall Street Journal Book): Books: Monica Langley',
#        'Meditations for Self Healing and Inner Power: Books: Joan Borysenko',
#        'Reef, The (Brilliance Audio on Compact Disc): Books: Nora Roberts,Sandra Burr',
#        "Davis's Drug Guide for Nurses: Books: Judith Hopfer Deglin,April Hazard Vallerand",
#        "You're Hired: How to Succeed in Business and Life from the Winner of The Apprentice: Books: Bill Rancic",
#        'Odd Thomas: A Novel (Koontz, Dean R.): Books: Dean Koontz',
#        'The Conservative Mind: From Burke to Eliot: Books: Russell Kirk',
#        'The Little White Horse: Books: Elizabeth Goudge',
#        'The Broom of the System: Books: David Foster Wallace',
#        'Behold a Pale Horse: Books: William Cooper,Milton William Cooper',
#        'The magic of thinking big: Books: David Joseph Schwartz',
#        '"A Trade like Any Other": Female Singers and Dancers in Egypt: Books: Karin van Nieuwkerk',
#        'Beyer on Speed: Books: Andrew Beyer',
#        'Answered Prayers (Danielle Steel): Books: Danielle Steel',
#        'A Primer of Drug Action: A Concise, Non-Technical Guide to the Actions, Uses, and Side Effects of Psychoactive Drugs: Books: Robert M. Julien',
#        'Fierce Conversations: Achieving Sucess at Work and in Life One Conversation at a Time: Books: Susan Scott',
#        'Target Iran: Books: Scott Ritter',
#        'Ashtanga Yoga: The Practice Manual: An Illustrated Guide to Personal Practice: Books: David Swenson',
#        'What Liberal Media?: The Truth About Bias and the News: Books: Eric Alterman',
#        'Time and Again: Books: Jack Finney',
#        "Who's Looking Out for You: Books: Bill O'Reilly",
#        'Rich Woman: A Book on Investing for Women - Because I Hate Being Told What to Do!: Books: Kim Kiyosaki',
#        'What I Know for Sure: My Story of Growing Up in America: Books: Tavis Smiley',
#        'Building Security: Handbook for Architectural Planning and Design: Books: Barbara A. Nadel',
#        'The Think and Grow Rich Action Pack: Books: Napoleon Hill',
#        "Women on Top: How Real Life Has Changed Women's Sexual Fantasies: Books: Nancy Friday",
#        'Otherwise: Three Novels: Books: John Crowley',
#        'How to Survive and Prosper as an Artist, 5th ed.: Selling Yourself Without Selling Your Soul: Books: Caroll Michels',
#        'Modern Times  Revised Edition: World from the Twenties to the Nineties, The (Perennial Classics): Books: Paul M. Johnson',
#        'Night: Books: Elie Wiesel',
#        'Power and Persuasion: How to Command Success in Business and Your Personal Life: Books: Michael Masterson,Agora',
#        'Home Dog: Books: Richard A. Wolters',
#        'The Fortune at the Bottom of the Pyramid: Eradicating Poverty Through Profits (The Wharton Press Paperback Series): Books: CK Prahalad',
#        'American Pastoral: Books: Philip Roth',
#        'How to Speak Dog: Mastering the Art of Dog-Human Communication: Books: Stanley Coren',
#        'Healing Touch: A Guide Book for Practitioners, 2nd edition (Healer Series): Books: Dorothea Hover-Kramer',
#        'A Guide to Prayer for Ministers and Other Servants: Books: Rueben P. Job,Norman Shawchuck',
#        'Homeschooling: The Teen Years: Your Complete Guide to Successfully Homeschooling the 13- to 18- Year-Old (Prima Home Learning Library): Books: Cafi Cohen,Janie Levine Hellyer',
#        'Catch Me If You Can: Books: Frank W. Abagnale,Barrett Whitener',
#        "The Complete Book of Chicken: Turkey, Game Hen, Duck, Goose, Quail, Squab, and Pheasant: Books: Cook's Illustrated",
#        'The Hostile Hospital (A Series of Unfortunate Events, Book 8): Books: Lemony Snicket,Brett Helquist',
#        'The Complete Guide to Buying and Selling Apartment Buildings: Books: Steve Berges',
#        'Bogle on Mutual Funds: New Perspectives for the Intelligent Investor: Books: John Bogle',
#        'Waiting for Godot: A Tragicomedy in Two Acts: Books: Samuel Beckett',
#        'New Faculty: A Practical Guide for Academic Beginners: Books: Christopher J. Lucas,John W. Murry',
#        '100,000 + Baby Names: The Most Complete Baby Name Book: Books: Bruce Lansky',
#        'The Lady   Sons Savannah Country Cookbook Collection: Books: Paula H. Deen',
#        'Complete Illustrated Guide to Cat Care: Books: Bruce Fogle,A. T. B. Edney',
#        'Last Days of Summer: Books: Steve Kluger',
#        'The House: Books: Danielle Steel',
#        'On Death and Dying: Books: Elisabeth Kubler-Ross',
#        'Shakespeare After All: Books: Marjorie Garber',
#        'Clear and Present Danger (Jack Ryan Novels): Books: Tom Clancy',
#        'The Night Gardener: Books: George Pelecanos,Author',
#        'Harry Potter and the Chamber of Secrets (Book 2): Books: J. K. Rowling,Mary GrandPr�',
#        'Healing from the Heart: A Leading Surgeon Combines Eastern and Western Traditions to Create the Medicine of the Future: Books: Mehmet Oz M.D.,Mehmet Oz,Dean Ornish',
#        "Cormac McCarthy's All the Pretty Horses: A Reader's Guide (Continuum Contemporaries): Books: Stephen Tatum",
#        'Beat the Market: A Scientific Stock Market System: Books: Edward O. Thorp',
#        "Hiring the Best:  Manager's Guide to Effective Interviewing and Recruiting, Fifth Edition: Books: Martin Yate,Martin John Yate",
#        'How Should We Then Live?: The Rise and Decline of Western Thought and Culture: Books: Francis A. Schaeffer,Lane T. Dennis',
#        'Reinventing Khomeini The Struggle for Reform in Iran: Books: Daniel Brumberg',
#        'After the Merger: The Authoritative Guide for Integration Success, Revised Edition: Books: Price Pritchett',
#        'Eldest (Inheritance, Book 2): Books: Christopher Paolini',
#        'Spring Snow: Books: Yukio Mishima',
#        'On Becoming Baby Wise: The Classic Sleep Reference Guide Used by Over 1,000,000 Parents Worldwide: Books: Gary Ezzo,Robert Bucknam',
#        'Fun Works: Creating Places Where People Love to Work: Books: Leslie Yerkes',
#        "Morrigan's Cross (The Circle Trilogy, Book 1): Books: Nora Roberts,Dick Hill",
#        'Encyclopedia of Gay Histories and Cultures: Volume 2 (Special - Reference): Books: G. Haggerty',
#        'Prayers for Rain (G K Hall Large Print Book Series): Books: Dennis Lehane',
#        '30-Minute Meals 2: Books: Rachael Ray',
#        'Mommies Who Drink: Sex, Drugs, and Other Distant Memories of an Ordinary Mom: Books: Brett Paesel',
#        'Into the Storm: A Novel: Books: Suzanne Brockmann',
#        'Never Eat Alone: And Other Secrets to Success, One Relationship at a Time: Books: Keith Ferrazzi,Tahl Raz',
#        'Origin In Death (In Death (Paperback)): Books: J. D. Robb',
#        'Thorndike Nonfiction - Large Print - Moneyball: The Art Of Winning An Unfair Game (Thorndike Nonfiction - Large Print): Books: Michael Lewis',
#        "Blue Shoes and Happiness: The New Novel in the No. 1 Ladies' Detective Agency Series (No. 1 Ladies Detective Agency): Books: Alexander Mccall Smith",
#        'Shaped by the Word: The Power of Scripture in Spiritual Formation: Books: M. Robert, Jr. Mulholland',
#        'How to Think Like Benjamin Graham and Invest Like Warren Buffett: Books: Lawrence A. Cunningham',
#        'National Geographic Almanac of World History (National Geographic Almanacs): Books: Pat Daniels,Steve Hyslop',
#        'Legend   Legacy:  The Story of Boeing and Its People: Books: Robert J. Serling',
#        'The One Percent Doctrine: Books: Ron Suskind',
#        'Real Simple Solutions: Tricks, Wisdom and Easy Ideas to Simplify Everyday: Books: Editors of Real Simple Magazine',
#        "Merriam Webster Children's Dictionary: Books: DK Publishing",
#        'All the Pretty Horses: Books: Cormac McCarthy',
#        'Technology and the Future: Books: Albert H. Teich',
#        "The Wal-Mart Way: The Inside Story of the Success of the World's Largest Company: Books: Don Soderquist",
#        'What Matters Most: How a Small Group of Pioneers Is Teaching Social Responsibility to Big Business, and Why Big Business Is Listening: Books: Jeffrey Hollender,Stephen Fenichell',
#        "Hegemony or Survival: America's Quest for Full Spectrum Dominance [The American Empire Project]: Books: Noam Chomsky,Brian Jones",
#        'Carrie (G.K. Hall Large Print Book): Books: Stephen King',
#        'Consensus Through Conversation: How to Achieve High-Commitment Decisions: Books: Larry Dressler',
#        "Nature's Metropolis: Chicago and the Great West: Books: William Cronon",
#        'The Moral Judgment of the Child: Books: JEAN PIAGET',
#        "The Reporter's Notebook : Writing Tools for Student Journalists: Books: Mark Levin",
#        'Mythology: DC Comics Art of Alex Ross 2007 Calendar: Books: Alex Ross',
#        'There Are No Children Here: The Story of Two Boys Growing Up in The Other America: Books: Alex Kotlowitz',
#        "Washington's Crossing (Pivotal Moments in American History): Books: David Hackett Fischer",
#        "OK, So Now You're a Vegetarian: Advice and 100 Recipes from One Vegetarian to Another: Books: Lauren Butts",
#        'My Life: Books: Bill Clinton',
#        'A History of Civilizations: Books: Fernand Braudel,Richard Mayne',
#        'SAP BW: A Step by Step Guide for BW 2.0: Books: Biao Fu,Henry Fu',
#        'The Italian Way: Books: Mario Costantino,Lawrence R. Gambella',
#        'Understanding and Using English Grammar (Azar English Grammar S.): Books: Betty Schrampfer Azar',
#        'Nation and Its Fragments: Books: Chatterjee',
#        'Anne of Avonlea: Books: Lucy Maud Montgomery',
#        "I Love My Dog, But...:: The Ultimate Guide To Managing Your Dog's Misbehavior: Books: Joy Tiz",
#        'Bridget Jones Diary: Books: Helen Fielding,Tracie Bennett',
#        'What the Ancient Wisdom Expects of Its Disciples: Books: Manly P. Hall',
#        'The Killer Angels: Books: Michael Shaara',
#        'Writing Horror (Self-Counsel Writing): Books: Edo Van Belkom',
#        'Cities of the Plain: Books: Cormac McCarthy',
#        'It: Books: Stephen King',
#        'Get Healthy Now! with Gary Null: A Complete Guide to Prevention, Treatment and Healthy Living (Second Edition): Books: Gary Null',
#        'The Lost Colony (Artemis Fowl, Book 5): Books: Eoin Colfer',
#        '7-Day Detox Miracle, Revised 2nd Edition: Revitalize Your Mind and Body with This Safe and Effective Life-Enhancing Program: Books: Peter Bennett,Sara Faye,Stephen Barrie',
#        'Terrible Honesty: Mongrel Manhattan in the 1920s: Books: Ann Douglas',
#        'Mathematics in Western Culture (Galaxy Books): Books: Morris Kline',
#        "Nietzsche's Gift: Books: Harold Alderman",
#        "River's End: Books: Nora Roberts",
#        "The Forewarned Investor: Don't Get Fooled Again by Corporate Fraud: Books: Brett S. Messing,Steven A. Sugarman,Jim Cramer",
#        'Consent to Kill: A Thriller: Books: Vince Flynn,George Guidall',
#        'What Your Doctor May Not Tell You About Menopause: The Breakthrough Book on Natural Progesterone: Books: John R. Lee,Virginia Hopkins',
#        'Skeletons on the Zahara: A True Story of Survival: Books: Dean King',
#        'The History of the Peloponnesian War: Revised Edition (Penguin Classics): Books: Thucydides,M. I. Finley,Rex Warner',
#        'Mockingbird: Books: Sean Stewart',
#        'Left Is Right: The Survival Guide for Living Lefty in a Right-Handed World: Books: Rae Lindsay',
#        'Economics in One Lesson: 50th Anniversary Edition: Books: Henry Hazlitt',
#        'Pegasus Descending: A Dave Robicheaux Novel (Dave Robicheaux Mysteries): Books: James Lee Burke',
#        'Secrets of the Millionaire Mind: Mastering the Inner Game of Wealth: Books: T. Harv Eker',
#        "The Global Class War : How America's Bipartisan Elite Lost Our Future - and What It Will Take to Win it Back: Books: Jeff Faux",
#        'Handbook of Applied Dog Behavior and Training, Volume Two: Etiology and Assessment: Books: Steven R. Lindsay',
#        'Babies With Down Syndrome: A New Parents Guide: Books: Karen Stray-Qundersen',
#        'Amazing Beginning of You, The: Books: Lisa Jacobson,Matt Jacobson,Jared Lee',
#        "Wanda Hickey's Night of Golden Memories: And Other Disasters: Books: Jean Shepherd",
#        'Eye of the Wolf: Books: Margaret Coel',
#        'What Remains: A Memoir of Fate, Friendship, and Love: Books: Carole Radziwill',
#        'Venture Capital and Private Equity: A Casebook: Books: Josh Lerner,Felda Hardymon,Ann Leamon',
#        'How to Write a Damn Good Novel: A Step-by-Step No Nonsense Guide to Dramatic Storytelling (How to Write a Damn Good Novel): Books: James N. Frey',
#        'The Everything College Cookbook: 300 Hassle-Free Recipes For Students On The Go (Everything: Cooking): Books: Rhonda Lauret Parkinson,Rhonda Lauret Parkinson',
#        'Just A Theory: Exploring The Nature Of Science: Books: Moti Ben-Ari',
#        'On Being Ill: Books: Virginia Woolf',
#        "Oh, Solo Mia! : The Hip Chick's Guide to Fun for One: Books: Wendy Burt,Erin Kindberg",
#        'Guns, Germs, and Steel: The Fates of Human Societies: Books: Jared Diamond',
#        'End Time Delusions: The Rapture, the Antichrist, Israel, and the End of the World: Books: Steve Wohlberg',
#        'An Anthropologist On Mars: Seven Paradoxical Tales: Books: Oliver Sacks',
#        'Work Hard, Study...and Keep Out of Politics! Adventures and Lessons from an Unexpected Public Life: Books: James Baker III',
#        'The Sacred Romance Workbook and Journal: Your Personal Guide for Drawing Closer to the Heart of God: Books: John Eldredge',
#        "World's Fairs and the End of Progress: An Insider's View: Books: Alfred Heller",
#        'Our Musicals, Ourselves: A Social History of the American Musical Theater: Books: John Bush Jones',
#        'When Society Becomes an Addict: Books: Anne Wilson Schaef',
#        "If the Gods Had Meant Us to Vote, They'd Have Given Us Candidates: Books: Jim Hightower",
#        'The Rough Guide to Cult Fiction (Rough Guides Reference Titles): Books: Michaela Bushell, Helen Rodiss Paul Simpson',
#        'Write Up the Corporate Ladder: Successful Writers Reveal the Techniques That Help You Write with Ease and Get Ahead: Books: Kevin Ryan',
#        'Thirteen Stories and Thirteen Epitaphs: Books',
#        'Blood Memory: A Novel: Books: Greg Iles',
#        'Inside My Heart: Choosing to Live with Passion and Purpose: Books: Robin McGraw',
#        'Why I Jumped: My True Story of Postpartum Depression, Dramatic Rescue   Return to Hope: Books: Tina Zahn,Wanda Dyson',
#        'Maximum Ride: Books: James Patterson',
#        'The Cold Moon: A Lincoln Rhyme Novel (Lincoln Rhyme Novels (Hardcover)): Books: Jeffery Deaver',
#        'Stars Beneath the Sea: The Pioneers of Diving: Books: Trevor Norton',
#        'Adobe Photoshop CS2 Classroom in a Book: Books: Adobe Creative Team',
#        'The Body Project: An Intimate History of American Girls: Books: Joan Jacobs Brumberg',
#        'Christian Wisdom of the Jedi Masters: Books: Dick Staub',
#        'Theft: A Love Story: Books: Peter Carey',
#        "Darwin's Dangerous Idea: Evolution and the Meanings of Life: Books: Daniel Clement Dennett",
#        'World Christian Encyclopedia: A Comparative Survey of Churches and Religions in the Modern World Volume I: The World by Countries: Religionists, Churches, Ministries: Books: David B. Barrett,George Thomas Kurian,Todd M. Johnson',
#        'Bowling Alone: The Collapse and Revival of American Community: Books: Robert D. Putnam',
#        'The Original 365 Cats Page-A-Day Calendar 2007 (Large Page-A-Day): Books: Workman Publishing Company',
#        'Lost in a Good Book (Thursday Next Novels): Books: Jasper Fforde',
#        'Etica/ethics: La Unica Regla Para Tomar Deciones/the Only Rule to Make Decisions: Books: John C. Maxwell',
#        'Thin Again: A Biblical Approach to Food, Eating and Weight Management: Books: Arthur W., M.D. Halliday,Judy Wardell Halliday',
#        'The Kiss (Random House Large Print): Books: Danielle Steel',
#        'Checking Your Grammar: Scholastic Guides: Books: Marvin Terban',
#        'Blue Smoke: Books: Nora Roberts,Joyce Bean',
#        "The Power of Persuasion: How We're Bought and Sold: Books: Robert V. Levine",
#        'Scholastic Dictionary of Synonyms, Antonyms, and Homonyms: Books',
#        'Alexander and the Terrible, Horrible, No Good, Very Bad Day CD: Books: Judith Viorst,Danner Blythe',
#        'Conspiracy in Death (In Death (Paperback)): Books: J. D. Robb,Nora Roberts',
#        'Sunday Suppers at Lucques: Seasonal Recipes from Market to Table: Books: Suzanne Goin,Teri Gelber',
#        'The Diary of a Young Girl: The Definitive Edition: Books: Anne Frank,Otto M. Frank,Mirjam Pressler,Susan Massotty',
#        "Beating the Dow with Bonds : A High-Return, Low-Risk Strategy for Outperforming the Pros Even When Stocks Go South: Books: Michael B. O'Higgins,Perkins Jack",
#        'Dateline Jerusalem: Books: Zola Levitt',
#        'Millionaire Women: Books: Jeanne Torrence Hauer',
#        "Tacoma Confidential: A True Story of Murder, Suicide, and a Police Chief's Secret Life: Books: Paul LaRosa",
#        'London Labour and the London Poor (Penguin Classics): Books: Henry Mayhew,Victor E. Neuburg',
#        'The Physics of Immortality: Modern Cosmology, God and the Resurrection of the Dead: Books: Frank J. Tipler',
#        'The essays of Warren Buffett: Lessons for corporate America: Books: Warren Buffett',
#        'Waiting for Godot: Books: Samuel Beckett',
#        'Sound and Fury: Two Powerful Lives, One Fateful Friendship: Books: Dave Kindred',
#        'Whalestoe Letters: Books: Mark Z. Danielewski',
#        'Teach Yourself Photography: Books: Lee Frost',
#        'The Looming Tower: Al-Qaeda and the Road to 9/11: Books: Lawrence Wright,Alan Sklar',
#        'Lies Across America: What Our Historic Sites Get Wrong: Books: James W. Loewen',
#        'A Confession: Books: Leo Tolstoy',
#        "What's So Great About America: Books: Dinesh D'Souza",
#        'Rental Houses for the Successful Small Investor: Books: Suzanne P. Thomas',
#        "Gravity's Rainbow (Penguin Twentieth-Century Classics): Books: Thomas Pynchon",
#        'Dead End: A Novel: Books: Mariah Stewart',
#        "Mastering the Trade (McGraw-Hill Trader's Edge): Books: John F. Carter",
#        'The Irresistible Offer: How to Sell Your Product or Service in 3 Seconds or Less: Books: Mark Joyner',
#        'Brando: Songs My Mother Taught Me: Books: Marlon Brando',
#        'Use What You Have Decorating : Transform Your Home in One Hour With Ten Simple Design Principles -- Using the Space You Have, the Things You Like, the Budget You Choose: Books: Lauri Ward',
#        "The Writer's Book of Hope: Getting from Frustration to Publication: Books: Ralph Keyes",
#        'Raising a Reader; Make Your Child a Reader for Life: Books: Paul Kropp',
#        'Reef, The: Books: Nora Roberts,Sandra Burr',
#        'The Perspective of the World: Civilization and Capitalism 15Th-18th Century, Vol. 3: Books: Fernand Braudel',
#        'The Meaning Of Life: Books: Bradley Trevor Greive',
#        'For Love of the Game: Books: Michael Shaara',
#        'John Adams: Books: David McCullough,Edward Herrmann',
#        "Protecting Your #1 Asset : Creating Fortunes from Your Ideas : An Intellectual Property Handbook (Rich Dad's Advisors): Books: Michael A. Lechter,Robert T. Kiyosaki",
#        'Endangered Species (Anna Pigeon Mysteries (Paperback)): Books: Nevada Barr',
#        'Longitudes and Attitudes: The World in the Age of Terrorism: Books: Thomas L. Friedman',
#        'Capitalism and Freedom (Phoenix Books): Books: Milton Friedman',
#        'A Library of Unfortunate Events, Books 1-10 (The Bad Beginning, The Reptile Room, The Wide Window, The Miserable Mill, The Austere Academy, The Ersatz Elevator, The Vile Village, The Hostile Hospital, The Carnivorous Carnival, The Slippery Slope) [SHRINK WRAPPED]: Books: Lemony Snicket,Brett Helquist',
#        'On Top of Spaghetti...: ...Macaroni, Linguine, Penne, and Pasta of Every Kind: Books: Johanne Killeen,George Germon',
#        'The Good House: Books: Tananarive Due',
#        'The Intelligence of Dogs: A Guide to the Thoughts, Emotions, and Inner Lives of Our Canine Companions: Books: Stanley Coren',
#        'The Devil in the White City:  Murder, Magic, and Madness at the Fair That Changed America: Books: Erik Larson',
#        'The Dog Chapel: Welcome All Creeds, All Breeds. No Dogmas Allowed: Books: Stephen Huneck',
#        'Dazzling Disguises and Clever Costumes: Books: Angela  Wilkes,Angela Wilkes',
#        'Bag of Bones: Books: Stephen King',
#        'Wait Till Next Year : A Memoir (AUDIO CASSETTE): Books: Doris Kearns Goodwin',
#        'Time Off for Good Behavior: Books: Lani Diane Rich',
#        'How to Get a Business Loan: Books: Joseph R. Mancuso',
#        "Russian Debutante's Handbook: Books: Gary Shteyngart",
#        'Cool Careers for Dummies: Books: Marty  PhD Nemko',
#        'Holidays on Ice: Books: David Sedaris,Ann Magnuson,Amy Sedaris',
#        'Teaching to change lives: Books: Howard G Hendricks',
#        'The Secret Code of the Superior Investor: How to Be a Long-Term Winner in a Short-Term World: Books: James Glassman',
#        'The Stand: Books: Stephen  King',
#        'The Cottage: Books: Danielle Steel',
#        'What to Expect the First Year, Second Ed: Books: Heidi Murkoff,Sandee Hathaway,Arlene Eisnberg',
#        "Suzanne Somers' Eat Great, Lose Weight: Books: Suzanne Somers,Barbara M. Dixon",
#        "The Way It's Never Been Done Before: My Friendship with Marlon Brando: Books: George Englund",
#        'Ark Angel (Alex Rider Adventures (Audio)): Books: Anthony Horowitz',
#        'Food and Culture: Books: Carole Counihan,Penny Van Esterik',
#        "Patton's One-Minute Messages: Tactical Leadership Skills of Business Managers: Books: Charles Province",
#        'Lost Chicago: Books: David Garrard Lowe',
#        'Dead and Doggone: Books: Susan Conant',
#        'Bone Palace Ballet: New Poems: Books: Charles Bukowski',
#        'Joy of Cooking: All About Grilling: Books: Irma S. Rombauer,Marion Rombauer Becker,Ethan Becker',
#        'Catch Me If You Can: Books: Frank W. Abagnale',
#        'Thin Tastes Better: Books: Stephen Phd Gullo',
#        'Men are from Mars Women are from Venus (Harper Audio): Books: John Gray,Gray John',
#        'Prophets of Regulation: Books: Thomas K. McCraw',
#        'The Genesis Code: Books: John Case',
#        'Mythology: The DC Comics Art of Alex Ross: Books: Alex Ross',
#        'Next : The Future Just Happened: Books: Michael Lewis',
#        'Never in Anger: Portrait of an Eskimo Family: Books: Jean L. Briggs',
#        'The Testament: Books: John Grisham',
#        "The Founder's Touch: The Life of Paul Galvin of Motorola: Books: Harry Mark Petrakis",
#        'Ten Big Ones: A Stephanie Plum Novel: Books: Janet Evanovich',
#        'While Europe Slept: How Radical Islam is Destroying the West from Within: Books: Bruce Bawer',
#        'The Rainmaker: Books: John Grisham',
#        'Studio Photography: Essential Skills (Photography Essential Skills): Books: John Child',
#        "Reflections on the Revolution in France (Oxford World's Classics): Books: Edmund Burke,L. G. Mitchell",
#        "Eye of the Wolf (John O'Malley and Vicki Holden Mysteries): Books: Margaret Coel",
#        'Monster: Living Off the Big Screen: Books: John Gregory Dunne',
#        'Anne of Avonlea: Books: L.M. Montgomery',
#        'Becoming a Master Student: Books: David Ellis',
#        'Get Fuzzy 2007 Day-to-Day Calendar: Books: Darby Conley',
#        'Impact: Fifty Short Stories: Books: Fannie Safier',
#        'Seductions Exposed: The Spiritual Dynamics of Relationships: Books: Gary L. Greenwald',
#        'LA Capital: The Biography of Mexico City: Books: Jonathan Kandell',
#        'Godel, Escher, Bach: An Eternal Golden Braid: Books: Douglas R. Hofstadter',
#        'Invisible Cities (A Harvest/Hbj Book): Books: Italo Calvino',
#        'I Hope They Serve Beer In Hell: Books: Tucker Max',
#        'Journey from the Land of No: A Girlhood Caught in Revolutionary Iran: Books: Roya Hakakian',
#        "A Child's Good Night Book Board Book: Books: Margaret Wise Brown,Jean Charlot",
#        'Discipline With Dignity: Books: Richard L. Curwin,Allen N. Mendler',
#        'As You Like It (Signet Classics (Paperback)): Books: William Shakespeare',
#        'Dreams of My Russian Summers: Books: Andrei Makine,Geoffrey Howard',
#        'HOW 9: A Handbook for Office Workers: Books: James L. Clark,Lyn R. Clark',
#        'Common Sense on Mutual Funds: New Imperatives for the Intelligent Investor: Books: John C. Bogle',
#        'Blood Memory: Books: Greg Iles',
#        'Possession: Books: A.S. Byatt,Leishman Virginia',
#        'Great Expectations: Books: Charles Dickens',
#        'When Harry Met Sally: Books: Nora Ephron',
#        'Everyone Worth Knowing: Books: Lauren Weisberger',
#        'Honest Illusions: Books: Nora Roberts',
#        "Writer's Guide to Book Editors, Publishers, and Literary Agents, 13th Edition (with CD-ROM): Who They Are! What They Want! And How to Win Them Over! (Writer's Guide): Books: Jeff Herman",
#        "Rich Dad's Guide to Investing: What the Rich Invest in, that the Poor and Middle Class Do Not! (Rich Dad's (Audio)): Books: Robert T. Kiyosaki,Sharon L. Lechter,Jim Ward",
#        'The Italians: Books: Luigi Barzini',
#        'Hard Way, The (Jack Reacher): Books: Lee Child,Dick Hill',
#        'The Lincoln Lawyer: Books: Michael Connelly,Adam Grupper',
#        'Miami: Books',
#        'D Is for Deadbeat (Kinsey Millhone Mysteries (Paperback)): Books: Sue Grafton',
#        'Irving Penn: Books: Irving Penn',
#        'Against the Tide: Books: Douglas A. Irwin',
#        'Laboratory Life: Books: Bruno Latour,Steve Woolgar,Jonas Salk',
#        'War of the Worlds (Dover Large Print Classics): Books: H. G. Wells',
#        'Transgressions: Books: Ed McBain',
#        'The Anti-Federalist Papers and the Constitutional Convention Debates: Books: Ralph Ketcham',
#        'The Husband: Books: Dean Koontz',
#        'Farmer in the Sky: Books: Robert A. Heinlein',
#        'In search of York: The slave who went to the Pacific with Lewis and Clark: Books: Robert B Betts',
#        'Microsoft  SharePoint   Products and Technologies Resource Kit (Pro - Resource Kit): Books: Bill English,Microsoft Corporation',
#        'The Pump House Gang: Books: Tom Wolfe',
#        'Travels with Charley in Search of America (Penguin Twentieth-Century Classics): Books: John Steinbeck,Jay Parini',
#        'For the Love of Greys: Books: Bobbi Brinker',
#        'Final Gifts: Understanding the Special Awareness, Needs, and Communications of the Dying: Books: Maggie Callanan,Patricia Kelley',
#        "Both Sides Now:  One Man's Journey Through Womanhood: Books: Dhillon Khosla",
#        'Sight Unseen: Books: Georgina Kleege',
#        'Living By The Book: Books: Howard Hendricks,William Hendricks',
#        'Think and Grow Rich: Books: Napoleon Hill,Joe Slattery',
#        'A Bend in the Road: Books: Nicholas Sparks,L. J. Ganser',
#        'The Constant Gardener: A Novel: Books: John le Carre',
#        'Lifeguard: Books: James Patterson,Andrew Gross,Billy Campbell',
#        'Never Be Lied To Again: Books: David J. Lieberman',
#        'Geography Club: Books: Brent Hartinger',
#        'Not for Tourists Guide to Chicago 2006 (Not for Tourists Guide to Chicago): Books: Jane Pirone',
#        'The Fall of the Roman Empire: A New History of Rome and the Barbarians: Books: Peter Heather',
#        'The Concept of Mind: Books: Gilbert Ryle',
#        'What Looks Like Crazy on an Ordinary Day: Books: Pearl Cleage',
#        "Understanding Iraq: The Whole Sweep of Iraqi History from Genghis Khan's Mongols to the Ottoman Turks to the British Mandate to the American Occupation: Books: William R. Polk",
#        'Fields Of Gold: Books: Marie Bostwick',
#        'The Deadline: A Novel About Project Management: Books: Tom Demarco',
#        'Natural Atheism: Books: David Eller',
#        'Chinese Lessons: Five Classmates and the Story of the New China: Books: John Pomfret',
#        'Leadership and the New Science: Learning About Organization from an Orderly Universe: Books: Margaret J. Wheatley',
#        'Kodak Guide to 35mm Photography: Techniques for Better Pictures: Books: Eastman Kodak Company',
#        'Hearts in Atlantis: Books: Stephen King',
#        'Role-Based Access Control: Books: David F. Ferraiolo,D. Richard Kuhn,Ramaswamy Chandramouli',
#        'The Tao of Pooh: Books: Benjamin Hoff',
#        'Math and Music: Harmonious Connections: Books: Trudi Hammel Garland,Charity Vaughan Kahn',
#        "Man's Rise to Civilization: The Cultural Ascent of the Indians of North America: Books: Peter Farb",
#        'Assassins: Assignment: Jerusalem, Target: Antichrist (Left Behind No. 6): Books: Tim F. LaHaye,Jerry B. Jenkins',
#        'The Penultimate Peril (A Series of Unfortunate Events, Book 12): Books: Lemony Snicket,Tim Curry',
#        'The Money Culture: Books: Michael Lewis',
#        "Front Row: Anna Wintour: What Lies Beneath the Chic Exterior of Vogue's Editor in Chief: Books: Jerry Oppenheimer",
#        'Mars and Venus Together Forever: Relationship Skills for Lasting Love: Books: John Gray',
#        'Carolina Moon (Nova Audio Books): Books: Nora Roberts,Dean Robertson (Narrator),J.D. Robb (Pseudonym)',
#        '201 Best Questions To Ask On Your Interview: Books: John Kador',
#        'Avenue Q - The Musical (Piano/Vocal arrangement): Books: Robert Lopez,Jeff Marx',
#        'The Addictive Personality: Understanding the Addictive Process and Compulsive Behavior: Books: Craig Nakken',
#        'Fearless Women: Midlife Portraits: Books: Nancy Alspaugh,Marilyn Kentz,Mary Ann Halpin',
#        "The War Against the Terror Masters: Why It Happened. Where We Are Now. How We'll Win.: Books: Michael A. Ledeen",
#        'The Fundamentals of Extremism: Books: Kimberly Blaker',
#        'The Debutante Divorcee: A Novel: Books: Plum Sykes',
#        'Grandfather: Books: Tom Brown',
#        'Built to Last: Successful Habits of Visionary Companies: Books: James C. Collins,Jerry I. Porras',
#        '20,000 Leagues Under the Sea (Tor Classics): Books: Jules Verne',
#        'Masque of the Red Death (Creative Short Stories S.): Books: Edgar Allan Poe',
#        'D is for Deadbeat (Sue Grafton): Books: Sue Grafton,Judy Kaye',
#        'Girl Wars: 12 Strategies That Will End Female Bullying: Books: Cheryl Dellasega,Charisse Nixon',
#        'Basic Photography, Seventh Edition: Books: Michael Langford',
#        'Elements of Style: Books: Wendy Wasserstein,Cynthia Nixon',
#        'Inner Peace for Busy People: 52 Simple Strategies for Transforming Your Life: Books: Joan Borysenko',
#        'Culture and Imperialism: Books: Edward W. Said',
#        'The Arctic Incident (Artemis Fowl, Book 2): Books: Eoin Colfer',
#        'Coming Out: Books: Danielle Steel',
#        'Carolina Moon: Books: Nora Roberts,Dean Robertson,J.D. Robb (Pseudonym)',
#        'A Breath of Snow and Ashes (Outlander): Books: Diana Gabaldon',
#        'Messenger, The: Books: Daniel Silva,Christopher Lane',
#        'Be * Know * Do, Adapted from the Official Army Leadership Manual: Leadership the Army Way (J-B Leader to Leader Institute/PF Drucker Foundation): Books: Richard Cavanagh,Frances Hesselbein,Eric K.   (USA Ret.) Shinseki',
#        "Light This Candle: The Life   Times of Alan Shepard--America's First Spaceman: Books: Neal Thompson",
#        'A Time to Kill (Random House Large Print): Books: John Grisham',
#        'Self-Promotion for the Creative Person: Get the Word Out About Who You Are and What You Do: Books: Lee Silber',
#        'Book Lust Journal: Books: Nancy Pearl',
#        'AJAX and PHP: Building Responsive Web Applications: Books: Cristian Darie,Bogdan Brinzarea,Filip Chereche #351;-To #351;a,Mihai Bucica',
#        'Absolute Trust in the Goodness of the Earth: Books: Alice Walker',
#        'The Joy of Cooking: Comb-Bound Edition: Books: Irma S. Rombauer,Marion Rombauer Becker',
#        'Two New Sciences: Including Centers of Gravity and Force of Percussion: Books: Galileo Galilei',
#        'Ashanti to Zulu: African Traditions (Picture Puffin Books (Paperback)): Books: Margaret Musgrove,Diane Dillon',
#        'Alpha Dogs: How Your Small Business can become a Leader of the Pack: Books: Donna Fenn',
#        'The 7-Day Low-Carb Rescue and Recovery Plan: For Every Low-Carb Dieter--On Any Program--Who Needs Real Help--Right Now: Books: Rachael F. Heller,Richard F. Heller',
#        'Taking Back Our Lives in the Age of Corporate Dominance: Books: Ellen Schwartz,Suzanne Stoddard',
#        'Hollywood: Books: Charles Bukowski',
#        "Power to the Patient: The Treatments to Insist on When You're Sick: Books: Isadore Rosenfeld",
#        'The 100 Best Companies to Work for in America: Books: Milton Moskowitz',
#        "The Know-It-All: One Man's Humble Quest to Become the Smartest Person in the World: Books: A. J. Jacobs",
#        "The Consumer's Guide to Effective Environmental Choices: Practical Advice from the Union of Concerned Scientists: Books: Michael Brower,Warren Leon",
#        'Inside Al Qaeda: Global Network of Terror: Books: Rohan Gunaratna',
#        'Simple Abundance: A Daybook of Comfort of Joy: Books: Sarah Ban Breathnach',
#        'The Night Before Christmas Pop-up: Books: Clement Clarke Moore,Robert Sabuda',
#        'The State of Nonprofit America: Books: Lester M. Salamon',
#        'Your Pregnancy Week-by-Week: Books: Glade B Curtis',
#        'How to Pick Pockets for Fun and Profit: A Magicians Guide to Pickpocket Magic: Books: Eddie Joseph,Bruce Fife',
#        'I Feel Bad About My Neck: And Other Thoughts on Being a Woman: Books: Nora Ephron',
#        'How to Quit Drugs for Good: A Complete Self-Help Guide: Books: Jerry Dorsman',
#        'Living on Luck: Selected Letters 1960S-1970s (Living on Luck Vol. 2): Books: Charles Bukowski,Seamus Cooney',
#        "Isaac's Storm: A Man, a Time, and the Deadliest Hurricane in History: Books: Erik Larson,Isaac Monroe Cline",
#        'The United States of Wal-Mart: Books: John Dicker',
#        "The Year's Best Fantasy and Horror: Ninth Annual Collection (Year's Best Fantasy and Horror): Books: Ellen Datlow,Terri Windling",
#        'Stocks for the Long Run: Books: Jeremy J. Siegel',
#        'The Arab-Israeli wars: War and peace in the Middle East: Books: Chaim Herzog',
#        'How to Develop Self-Confidence And Influence People By Public Speaking: Books: Dale Carnegie',
#        "The Experts' Guide to the Baby Years: 100 Things Every Parent Should Know: Books: Samantha Ettus",
#        '3-D Geometric Origami: Books: Rona Gurkewitz,Bennett Arnstein',
#        'The Art of Looking Sideways: Books: Alan Fletcher',
#        "Allen and Greenough's New Latin Grammar (HardCover) (Focus Texts: For Classical Language Study): Books: J.B. Greenough,G. L. Kittredge,A.A. Howard,Benj. L. D'Ooge,Anne Mahoney,J.H. Allen",
#        'The Cambridge Companion to Jane Austen (Cambridge Companions to Literature): Books: Edward Copeland,Juliet McMaster',
#        'Pulp: Books: Charles Bukowski',
#        'The Complete Calvin and Hobbes: Books: Bill Watterson',
#        "Free L.A. The Ultimate Free Fun Guide to the City of Angels (Los Angeles): Books: Robert Stock,Alisha L. Semchuck,Joe Tortomasi,Susan Carrier,Desiree Zamorano,Ron O'Brien,Troy Corley",
#        'The Finer Points of Sausage Dogs: Books: Alexander McCall Smith',
#        'The Fate of the Corps: What Became of the Lewis and Clark Explorers After the Expedition: Books: Larry E. Morris',
#        'The Well-Ordered Home: Organizing Techniques for Inviting Serenity into Your Life: Books: Kathleen Kendall-Tackett',
#        "Not Your Mother's Life: Changing the Rules of Work, Love, and Family: Books: Joan K. Peters",
#        "Susannah's Garden (MIRA Single Title Hardbacks): Books: Debbie Macomber",
#        'Blessings: Books: Anna Quindlen',
#        'China Inc.: How the Rise of the Next Superpower Challenges America and the World: Books: Ted C Fishman,Alan Sklar',
#        'Baby Laughs: The Naked Truth About the First Year of Mommyhood: Books: Jenny McCarthy',
#        'The Finishing School: Earning the Navy SEAL Trident: Books: Dick Couch',
#        'May the Best Team Win: Baseball Economics and Public Policy: Books: Andrew Zimbalist',
#        'The Woman In White  [UNABRIDGED] (Classic Books on Cassettes Collection) (Classic Books on Cassettes Collection): Books: Wilkie Collins,Flo Gibson',
#        'Third Down and a War to Go: The All-American 1942 Wisconsin Badgers: Books: Terry Frei',
#        'On Stage: Theater Games and Activities for Kids: Books: Lisa Bany-Winters',
#        "Volcanoes (Let's-Read-and-Find-Out Science 2): Books: Franklyn M. Branley,Marc Simont",
#        'The Forgotten: Books: Elie Wiesel',
#        'A Separate Peace: Books: John Knowles',
#        "My Sister's Keeper: A Novel (Picoult, Jodi): Books: Jodi Picoult",
#        'Holidays on Ice: Stories: Books: David Sedaris',
#        'Beggar in Jerusalem: Books: Elie Wiesel',
#        'E Is for Evidence: A Kinsey Millhone Mystery (Large Print): Books: Sue Grafton',
#        'Banker to the Poor: Books: Muhammad Yunus,Alan Jolis',
#        "Rich Dad's Retire Young, Retire Rich : How to Get Rich Quickly and Stay Rich Forever!: Books: Robert T. Kiyosaki,Sharon L. Lechter,Jim Ward",
#        'Wigfield: The Can-Do Town That Just May Not: Books: Amy Sedaris,Paul Dinello,Stephen Colbert',
#        'Today in History: Disney (Today in History): Books: Eve Zibart',
#        'Skeleton Man: Books: Tony Hillerman',
#        'Choosing a Dog for Dummies: Books: Chris Walkowicz',
#        'The Decline of the West (Oxford Paperbacks): Books: Oswald Spengler,Helmut Werner,H. Stuart Hughes,Arthur Helps,Charles Francis Atkinson',
#        'Sojourn: The Legend of Drizzt, Book III (The Legend of Drizzt): Books: R.A. Salvatore',
#        'Redeeming Creation: The Biblical Basis for Environmental Stewardship: Books: Fred Van Dyke,David C. Mahan,Joseph K. Sheldon,Raymond H. Brand',
#        'Mystic River: Books: Dennis Lehane',
#        'Jurgen: Books: James Branch Cabell',
#        'Mastering the Art of French Cooking, Vol. 1: Books: Julia Child,Simone Beck,Louisette Bertholle',
#        'American Movie Critics: From the Silents Until Now (Library of America (Hardcover)): Books: Phillip Lopate',
#        'Black Order: A Novel (Sigma Force Novels): Books: James Rollins',
#        'The Pawprints of History: Dogs and the Course of Human Events: Books: Stanley Coren',
#        'The Bone Lady: Life as a Forensic Anthropologist: Books: Mary H. Manheim',
#        'Africa: A Modern History: Books: Guy Arnold',
#        "Literature Lover's Book Of Lists : Serious Trivia for the Bibliophile: Books: Judie L. H. Strouf,Judie L.H. Strouf",
#        'Season of Life: A Football Star, a Boy, a Journey to Manhood: Books: Jeffrey Marx',
#        'Origins of the Civil Rights Movements: Books: Aldon D. Morris',
#        "McDonald's: Behind The Arches: Books: John F. Love",
#        'Travels with Charley in Search of America: Books: John Steinbeck',
#        'Out of Control: The New Biology of Machines, Social Systems and the Economic World: Books: Kevin Kelly',
#        'Faith of My Fathers: Books: John Mccain,Mark Salter',
#        'Managing Projects Large and Small: The Fundamental Skills to Deliver on Cost and on Time: Books: Harvard Business School Press',
#        'Orchid Blues (Holly Barker Novels): Books: Stuart Woods',
#        'A Bright Shining Lie: John Paul Vann and America in Vietnam: Books: Neil Sheehan',
#        'Making Music Modern: New York in the 1920s: Books: Carol J. Oja',
#        'Nathaniel Hawthorne : Tales and Sketches (Library of America): Books: Nathaniel Hawthorne',
#        "3rd Degree (Women's Murder Club (Paperback)): Books: James Patterson,Andrew Gross",
#        "The Bells of Victory: The Pitt-Newcastle Ministry and Conduct of the Seven Years' War 1757-1762: Books: Richard Middleton",
#        'The Guardian: Books: Nicholas Sparks',
#        'AIA Guide to Chicago: Second Edition (Harvest Original): Books: Alice Sinkevitch',
#        'Writing the New Economy: Books: John Middleton',
#        'Business Systems Engineering: Managing Breakthrough Changes for Productivity and Profit: Books: Gregory H. Watson',
#        "Kathy Santo's Dog Sense: Books: Kathy Santo",
#        'The Happiness Hypothesis: Books: Jonathan Haidt',
#        "Conquering Arthritis: What Doctors Don't Tell You Because They Don't Know: 9 Secrets I Learned the Hard Way: Books: Barbara D. Allan",
#        "Let Me Hear Your Voice: A Family's Triumph over Autism: Books: Catherine Maurice",
#        'The Last Odd Day: Books: Lynne Hinton',
#        'Strip Tease (Wheeler Large Print Book Series): Books: Carl Hiaasen',
#        'Photoshop CS / CS2 Wow! Book, The, 1/e (WOW!): Books: Linnea Dayton,Cristen Gillespie',
#        'Shiksa Goddess: (Or, How I Spent My Forties) Essays: Books: Wendy Wasserstein',
#        'Blood Memory: Books: Greg Iles,Joyce Bean',
#        'Free to Choose: A Personal Statement: Books: Milton Friedman',
#        'Nine Stories: Books: J.D. Salinger',
#        'Sea of Thunder: Four Commanders and the Last Great Naval Campaign 1941-1945: Books: Evan Thomas',
#        'The First Eagle (Jim Chee Novels): Books: Tony Hillerman',
#        "The Samurai's Garden: A Novel: Books: Gail Tsukiyama",
#        'The Wisdom of Menopause: Creating Physical and Emotional Health and Healing During the Change: Books: Christiane Northrup',
#        "Backfire: Carly Fiorina's High-Stakes Battle for the Soul of Hewlett-Packard: Books: Peter Burrows",
#        'The Prose Edda: Tales from Norse Mythology: Books: Snorri Sturluson',
#        'To Kill a Mockingbird: Books: Harper Lee',
#        'Collapse: How Societies Choose to Fail or Succeed: Books: Jared Diamond,Michael Prichard',
#        'What The Corpse Revealed: Books: Hugh Miller',
#        'The Things I Know Best: A Novel: Books: Lynne Hinton',
#        'Deep Change: Discovering the Leader Within (Jossey-Bass Business   Management Series): Books: Robert E. Quinn',
#        'The Runaway Bunny: Books: Margaret Wise Brown,Clement Hurd',
#        'Ten Stupid Things Couples Do to Mess Up Their Relationships: Books: Laura C. Schlessinger',
#        'The Great Bust Ahead: The Greatest Depression in American and UK History is Just Several Short Years Away. This is your Concise Reference Guide to Understanding Why and How Best to Survive It: Books: Daniel A. Arnold',
#        'The general theory of employment, interest and money: Books: John Maynard Keynes',
#        'Master of the Senate: The Years of Lyndon Johnson: Books: Robert A. Caro',
#        'A Great Improvisation: Franklin, France, and the Birth of America: Books: Stacy Schiff,Jason Culp',
#        'The Unfinished Revolution: Social Movement Theory and the Gay and Lesbian Movement (Cambridge Cultural Social Studies): Books: Stephen M. Engel',
#        "The Teen's Vegetarian Cookbook: Books: Judy Krizmanic,Matthew Wawiorka",
#        'Lifeguard: Books: James Patterson,Andrew Gross',
#        'Only the Paranoid Survive: How to Exploit the Crisis Points That Challenge Every Company: Books: Andrew S. Grove',
#        'Truth, Knowledge, Or Just Plain Bull: How To Tell The Difference : A Handbook of Practical Logic and Clear Thinking: Books: Bernard M. Patten',
#        'Sleeping with Fear (Fear (Hardcover)): Books: Kay Hooper',
#        "You'll See It When You Believe It: The Way to Your Personal Transformation: Books: Wayne W. Dyer",
#        'The Reptile Room (A Series of Unfortunate Events, Book 2): Books: Lemony Snicket,Brett Helquist',
#        'Dancing With Dragons: Books: D.J. Conway',
#        'My Name Is Red: Books: Orhan Pamuk,Erdag Goknar',
# ...
#        'Write the Perfect Book Proposal: 10 That Sold and Why, 2nd Edition: Books: Jeff Herman,Deborah Levine Herman',
#        'Possible Side Effects: Books: Augusten Burroughs',
#        'Still Here: Embracing Aging, Changing, and Dying: Books: Ram Dass',
#        'Nanotechnology Applications And Markets: Books: Lawrence Gasman',
#        'Affluenza: The All-Consuming Epidemic: Books: John De Graaf,David Wann,Thomas H. Naylor,Scott Simon,David Horsey',
#        'Speed Train Your Own Bird Dog: Books: Larry Mueller',
#        'Thorndike Basic - Large Print - Glorious Appearing: The End of Days (Thorndike Basic - Large Print): Books: Tim LaHaye and Jerry B. Jenkins',
#        'The Essential Agrarian Reader: The Future of Culture, Community, and the Land: Books: Barbara Kingsolver,Norman Wirzba',
#        'Trading for a Living: Psychology, Trading Tactics, Money Management: Books: Alexander Elder',
#        'Silverthorn (Riftwar Saga, Volume 3): Books: Raymond E. Feist',
#        'Six Masters of the Spanish Sonnet: Francisco De Quevedo, Sor Juana Ines De LA Cruz, Antonio Machado, Federico Garcia Lorca, Jorge Luis Borges, Migue: Books: Willis Barnstone',
#        '11 de septiembre (9-11, Spanish-Language Edition): Books: Noam Chomsky',
#        'How to Master the Art of Selling: Books: Tom Hopkins',
#        'How the West Grew Rich: The Economic Transformation of the Industrial World: Books: Nathan Rosenberg,L.E. Birdzell Jr.',
#        '101 Improv Games for Children and Adults: Books: Bob Bedore,Ian Barkley',
#        '20,000 Leagues Under the Sea: Books: Jules Verne',
#        'Game Management: Books: Aldo Leopold',
#        'Difficult Conversations: Books: Douglas Stone,Sheila Heen,Roger Fisher',
#        'The Opal Deception (Artemis Fowl, Book 4): Books: Eoin Colfer,Nathaniel Parker',
#        '301 Smart Answers to Tough Interview Questions: Books: Vicky Oliver',
#        'Healing Beyond the Body: Medicine and the Infinite Reach of the Mind: Books: Larry Dossey',
#        'Designs for Coloring: Geometrics (Designs for Coloring): Books: Ruth Heller',
#        'Dead Sleep: Books: Greg Iles',
#        'Genetics: An Introduction for Dog Breeders: Books: Jackie Isabell',
#        "Stephen King: America'S Best-Loved Boogeyman: Books: Beahm",
#        'Woof: Books: Elliott Erwitt',
#        'Be Safe!: Simple Strategies for Death-Free Living: Books: Melissa Heckscher',
#        'Guerrilla Marketing Excellence: The 50 Golden Rules for Small-Business Success (Guerrilla Marketing): Books: Jay Conrad Levinson',
#        'Murder at Five Finger Light: A Jessie Arnold Mystery: Books: Sue Henry',
#        'Blinded by the Right: The Conscience of an Ex-Conservative: Books: David Brock',
#        'Moss Hart: A Prince of the Theater: Books: Jared Brown',
#        'Good Dogs, Bad Habits: Books: Jeanne Carlson',
#        "Rules Of Play: Opposites Attract\\The Heart's Victory (Silhouette Romance): Books: Nora Roberts",
#        'Shadows of the Mind: A Search for the Missing Science of Consciousness: Books: Roger Penrose',
#        'Truman: Books: David McCullough',
#        "The Doctors Book of Home Remedies for Dogs and Cats: Over 1,000 Solutions to Your Pet's Problems-From Top Vets, Trainers, Breeders, and Other Animal Experts: Books: Prevention Magazine Health Book Staff",
#        "Programming in C (3rd Edition) (Developer's Library): Books: Stephen Kochan",
#        'Reading Lolita in Tehran: A Memoir in Books: Books: Azar Nafisi',
#        'The Crossing (Random House Large Print): Books: Cormac Mccarthy',
#        'The Manuscript Found in Saragossa (Penguin Classics): Books: Jan Potocki,Ian MacLean',
#        "Don't Know Much About History - Updated and Revised Edition: Everything You Need to Know about American History But Never Learned (Davis, Kenneth C. Don't Know Much.): Books: Kenneth C. Davis,Jeff Woodman,Jonathan Davis,John Beach,Sarah Hayon",
#        'Reading Lolita in Tehran: A Memoir in Books (Wheeler Large Print Book Series): Books: Azar Nafisi',
#        'Professional Excel Development: The Definitive Guide to Developing Applications Using Microsoft(R) Excel and VBA(R) (The Addison-Wesley Microsoft Technology Series): Books: Stephen Bullen,Rob Bovey,John Green',
#        'And the Band Played On: Politics, People and the AIDS Epidemic: Books: Randy Shilts',
#        'The Complete Brothers Grimm Fairy Tales: Books: Brothers Grimm',
#        'Under Orders (Thorndike Press Large Print Basic Series): Books: Dick Francis',
#        'Reinventing the CFO: How Financial Managers Can Transform Their Roles and Add Greater Value: Books: Jeremy Hope',
#        'The Transit of Venus: Books: Shirley Hazzard',
#        "All Aunt Hagar's Children: Stories: Books: Edward P. Jones",
#        'A Country of Strangers: Blacks and Whites in America: Books: David K. Shipler',
#        'The War of the Worlds (Books of Wonder): Books: H. G. Wells,Tom Kidd',
#        'The Kill Artist: Books: Daniel Silva',
#        'Martin Zweig Winning on Wall Street: Books: Martin Zweig',
#        'Aia Guide to Chicago: Books: American Institute of Architects Chicago Chapter,Chicago Architecture Foundation,Landmarks Preservation Council of Illinois,Alice Sinkevitch,Laurie McGovern Petersen',
#        'Affluenza: The All-Consuming Epidemic: Books: John De Graaf,David Wann,Thomas H. Naylor',
#        'The 48 Laws of Power: Books: Robert Greene',
#        'The Way of the Owl: Succeeding with Integrity in a Conflicted World: Books: Frank Rivers',
#        'The Joy Luck Club: A Novel: Books: Amy Tan',
#        'From the Land of Green Ghosts: A Burmese Odyssey: Books: Pascal Khoo Thwe',
#        'The Gifts of Athena: Historical Origins of the Knowledge Economy: Books: Joel Mokyr',
#        "Uncle Petros and Goldbach's Conjecture: A Novel of Mathematical Obsession: Books: Apostolos Doxiadis",
#        'Chic In Paris: Style Secrets and Best Addresses: Books: Susan Tabak',
#        'KJV Cameo Reference Edition (Black Calfskin Leather): Books: Bible',
#        'Democracy And Education: Books: John Dewey',
#        'Baby Dances, The: Books: Kathy Henderson,Tony Kerins',
#        'The Fortune at the Bottom of the Pyramid: Eradicating Poverty Through Profits: Books: C. K. Prahalad',
#        'Break No Bones: A Novel (Temperance Brennan Novels (Hardcover)): Books: Kathy Reichs',
#        "The Pre-Foreclosure Property Investor's Kit: How to Make Money Buying Distressed Real Estate -- Before the Public Auction: Books: Thomas Lucier",
#        "You Can't Cheat an Honest Man: How Ponzi Schemes and Pyramid Frauds Work... and Why They're More Common Than Ever: Books: James Walsh",
#        'The Third Reich in Power, 1933-1939: Books: Richard J. Evans',
#        'Fast Food Nation: The Dark Side of the All-American Meal: Books: Eric Schlosser',
#        'Qualitative Research and Case Study Applications in Education: Revised and Expanded from I Case Study Research in Education/I (Jossey Bass Education Series): Books: Sharan B. Merriam',
#        'Animals in Translation: Using the Mysteries of Autism to Decode Animal Behavior: Books: Temple Grandin,Catherine Johnson,Shelly Frasier',
#        'A Companion to the Crying of Lot 49: Books: J. Kerry Grant',
#        'The PMP Exam: How to Pass On Your First Try (Test Prep series): Books: PMP, Andy Crowe',
#        'The Andromeda strain: Books: Michael Crichton',
#        "Kant's Transcendental Idealism: An Interpretation and Defense: Books: Henry E. Allison",
#        'Taking a Chance on God: Liberating Theology for Gays, Lesbians, and Their Lovers, Families, and Friends: Books: John J. McNeill',
#        'Queen Without A Country: Books: Rachel Bard',
#        'Eaters of the Dead (Previously The 13th Warrior): Books: Michael Crichton',
#        'Million Little Pieces: Books: James Frey',
#        'The Great Fire: A Novel: Books: Shirley Hazzard',
#        'The Attractor Factor: 5 Easy Steps for Creating Wealth (or Anything Else) from the Inside Out: Books: Joe Vitale',
#        'Introduction to Phenomenology: Books: Dermot Moran',
#        'The Oxford Dictionary of Allusions: Books: Andrew Delahunty,Sheila Dignan,Penny Stock',
#        'Difficult Conversations: How to Discuss what Matters Most: Books: Douglas Stone,Bruce Patton,Sheila Heen,Roger Fisher',
#        'The Bedside Book of Birds: An Avian Miscellany: Books: Graeme Gibson',
#        'Top performance: how to develop excellence in yourself and o: Books: Zig Ziglar',
#        'Ziglar on Selling: The Ultimate Handbook for the Complete Sales Professional: Books: Zig Ziglar',
#        'I Wanna Take Me a Picture: Teaching Photography and Writing to Children: Books: Wendy Ewald,Alexandra Lightfoot',
#        'The Big Love: A Novel: Books: Sarah Dunn',
#        "Word Spy: The Word Lover's Guide to Modern Culture: Books: Paul Mcfedries",
#        'Dog Grooming For Dummies (For Dummies (Pets)): Books: Margaret H. Bonham',
#        'Odd Thomas: Books: Dean Koontz',
#        "The Traveler's Gift: Seven Decisions that Determine Personal Success: Books: Andy Andrews",
#        'The Restoration of Perfection: Labor and Technology in Medieval Culture: Books: George, Jr. Ovitt',
#        'Drama City: Books: George Pelecanos',
#        'Thinking with Type: A Critical Guide for Designers, Writers, Editors,   Students (Design Briefs): Books: Ellen Lupton',
#        'Justice Interruptus: Critical Reflections on the "Postsocialist" Condition: Books: Nancy Fraser',
#        'Planet of the Blind: Books: Stephen Kuusisto',
#        'Accounting Best Practices (Wiley Best Practices): Books: Steven M. Bragg',
#        "Oxford Fowler's Modern English Usage Dictionary: Books: H. W. Fowler,Ernest Gowers,Sir Ernest Gowers",
#        'The Destruction of the Bison: An Environmental History, 1750-1920 (Studies in Environment and History): Books: Andrew C. Isenberg',
#        'Management: Tasks, Responsibilities, Practices: Books: Peter F. Drucker',
#        'The Dog Whisperer: A Compassionate, Nonviolent Approach to Dog Training: Books: Paul Owens,Norma Eckroate',
#        'Lord John and the Private Matter: Books: Diana Gabaldon',
#        'The Great Transformation: Books: Karl Polanyi',
#        'Against the Gods: The Remarkable Story of Risk: Books: Peter L. Bernstein',
#        'Classical Music: Third Ear: The Essential Listening Companion: Books: Harold C. Schonberg,Alexander J. Morin',
#        'The Sexy Years: Discover the Hormone Connection--The Secret to Fabulous Sex, Great Health, and Vitality, for Women and Men: Books: Suzanne Somers',
#        'Hunt for Red October: Books: Tom Clancy',
#        'Leadership Without Easy Answers: Books: Ronald Heifetz',
#        'Bone Volume 2: The Great Cow Race: Books: Jeff Smith',
#        'The Rescue: Books: Nicholas Sparks',
#        'The Souls of Black Folk: Books: W.E.B. Du Bois',
#        'Genghis Khan: Life, Death, and Resurrection: Books: John Man',
#        "Motivating Students Who Don't Care: Successful Techniques for Educators: Books: Allen N. Mendler",
#        "Alexander, Who's Not (Do You Hear Me? I Mean It!) Going to Move: Books: Judith Viorst,Ray Cruz,Robin Preiss Glasser",
#        'The Campus Guide: Rice University: Books: Stephen Fox',
#        "Five Regions of the Future : Preparing Your Business for Tomorrow's Technology Revolution: Books: Joel Barker,Scott Erickson",
#        "Zig Ziglar's Secrets of Closing the Sale: Books: Zig Ziglar",
#        'A Time for Freedom: Books: Lynne Cheney',
#        'Many Lifetimes (Joan Grant Autobiography): Books: Joan Grant,Denys Kelsey',
#        'Agee on Film: Criticism and Comment on the Movies (Modern Library the Movies): Books: James Agee',
#        'The Diary of a Young Girl (Student Drama): Books: Frances Goodrich,Albert Hackett,Anne Frank',
#        'The Secret Code of the Superior Investor: How to be a Long-Term Winner in a Short-Term World: Books: James Glassman',
#        'Londonistan: Books: Melanie  Phillips',
#        'Tail-End Charlies: The Last Battles of the Bomber War, 1944-45: Books: John Nichol',
#        'Suttree: Books: Cormac McCarthy',
#        'Cool Careers for Dummies: Books: Marty Nemko,Paul Edwards,Sarah Edwards',
#        'The Da Vinci Code: Books: Dan Brown,Paul Michael',
#        'Built to Last : Successful Habits of Visionary Companies: Books: James Collins,Jerry Porras',
#        'Postwar: A History of Europe Since 1945: Books: Tony Judt',
#        'Grey Seas Under: Books: Farley Mowat',
#        'Christian Reflections on The Leadership Challenge: Books: John C. Maxwell,James M. Kouzes,Barry Z. Posner',
#        'The Best American Science and Nature Writing 2006 (The Best American Series (TM)): Books: Brian Greene,Tim Folger',
#        'Sleepwalk: and Other Stories: Books: Adrian Tomine',
#        "My Dog's Brain: Books: Stephen Huneck",
#        'What Is Total Quality Control?: The Japanese Way: Books: Kaoru Ishikawa',
#        'The Mind of the CEO: Books: Jeffrey E. Garten',
#        'Masterful Coaching: Books: Robert Hargrove',
#        'The Invisibles Vol. 1: Say You Want a Revolution: Books: Grant Morrison',
#        'When Bad Things Happen to Good People: Books: Harold S. Kushner',
#        'Living Through Breast Cancer: Books: Carolyn M. Kaelin,Francesca Coltrera',
#        'Cloudy With a Chance of Meatballs: Books: Judi Barrett',
#        'Dear John: Books: Nicholas Sparks,Holter Graham',
#        'The Way Things Are: The De Rerum Natura: Books: Lucretius,Rolfe Humphries,Rolfe (Translator) Humphries',
#        'The Electronic Day Trader: Successful Strategies for On-line Trading: Books: Marc Friedfertig,George West,George Piecznik',
#        'Wireless Communications: Books: Andrea Goldsmith',
#        'Amazing Grace: Lives of Children and the Conscience of a Nation, The: Books: Jonathan Kozol',
#        'Beating the Street: Books: Peter Lynch,John Rothchild',
#        'Disney Princess CD Storybook (4-In-1 Disney Audio CD Storybooks): Books: Inc. Penton Overseas',
#        'Mommy Knows Worst: Highlights from the Golden Age of Bad Parenting Advice: Books: James Lileks',
#        'Victims of Memory: Sex Abuse Accusations and Shattered Lives: Books: Mark Pendergrast',
#        'Tito and the Rise and Fall of Yugoslavia: And the Rise and Fall of Yugoslavia: Books: Richard West',
#        'Knitting for Anarchists: Books: Anna Zilboorg',
#        'Take the Cannoli : Stories From the New World: Books: Sarah Vowell',
#        'A Box of Rain: Lyrics: 1965-1993: Books: Robert Hunter',
#        'Bird by Bird: Some Instructions on Writing and Life: Books: Anne Lamott',
#        "River's End (Thorndike Large Print Basic Series): Books: Nora Roberts",
#        "Glencoe Literature � 2002 Course 7, Grade 12 British Literature : The Reader's Choice: Books: McGraw-Hill,Glencoe/ McGraw-Hill",
#        'The Cat Who Walks Through Walls: Books: Robert A. Heinlein',
#        "On Becoming a Person:  A Therapist's View of Psychotherapy: Books: Carl Rogers,Peter D. Kramer",
#        'Doubt: A History: The Great Doubters and Their Legacy of Innovation from Socrates and Jesus to Thomas Jefferson and Emily Dickinson: Books: Jennifer Michael Hecht',
#        "8 Choices That Will Change a Woman's Life: Books: Jill Brisco",
#        'The Walking Dead Vol. 3: Safety Behind Bars: Books: Robert Kirkman,Charlie Adlard',
#        'Made in Japan: Books: Akio Morita',
#        'Bringing Down the House: The Inside Story of Six M.I.T. Students Who Took Vegas for Millions: Books: Ben Mezrich',
#        'Daring to Dream: Books: Nora Roberts,Sandra Burr',
#        'Food security: A review of the concepts and an update on the realities in the AID-assisted LAC countries: Books: Roberta K Van Haeften',
#        "The Art of the Steal: How to Recognize and Prevent Fraud--America's #1 Crime: Books: Frank W. Abagnale",
#        'A history of interest rates: Books: Sidney Homer',
#        'The Villa (Random House Large Print): Books: Nora Roberts',
#        'Jurassic Park (G K Hall Large Print Book Series): Books: Michael Crichton',
#        "A Scented Palace: The Secret History of Marie Antoinette's Perfumer: Books: Elisabeth de Feydeau,Jane Lizop",
#        'Open Your Mind, Open Your Heart: Books: W. Marie Giles',
#        'Loving Monday: Succeeding in Business Without Selling Your Soul: Books: John D. Beckett'],
#       dtype=object)

# %%
df[df.product_name == 'Honest Illusions: Books: Nora Roberts']["review_text"].to_list()[0]
# Out:
# "I simply adore this book and it's what made me go out to buy every other Nora Roberts novel.  It just amazes me the chemistry between Luke and Roxanne.  Everytime I read it I can't get over the excitement and the smile it brings to me as they barb back and forth.  It's just an amazing story over the course of growing up together and how it all develops.  Roxanne is smart and sassy and Luke is just too cool.  This romantic duo shines and no one else compares to them yet for me.  My very favorite romance"

# %%
df2 = df[df.product_name == 'Honest Illusions: Books: Nora Roberts']
df2
# Out:
#                                product_name  \
# 2054  Honest Illusions: Books: Nora Roberts
# 2055  Honest Illusions: Books: Nora Roberts
# 2056  Honest Illusions: Books: Nora Roberts
# 2057  Honest Illusions: Books: Nora Roberts
# 2058  Honest Illusions: Books: Nora Roberts
# 2059  Honest Illusions: Books: Nora Roberts
# 2060  Honest Illusions: Books: Nora Roberts
#
#                                             review_text  \
# 2054  I simply adore this book and it's what made me...
# 2055  Magic, mystery, romance and burglary are all p...
# 2056  I read the review and got the book and fell in...
# 2057  It is difficult to find books in this genre th...
# 2058  This is one of my favorite Nora Roberts book. ...
# 2059  This book has everything....Love, Greed, Murde...
# 2060  When I began to read Nora Roberts, I really di...
#
#                               reviewer
# 2054           L. Cortes "Book Junkie"
# 2055  Terry A. Benedict-Devine "Terry"
# 2056                     Diana Faraone
# 2057                         A. Rowley
# 2058            avid reader "A reader"
# 2059                       S. Williams
# 2060                       Creekergirl

# %%
from snorkel.augmentation import PandasTFApplier, ApplyAllPolicy

tfs = [predict_next, augment_by_translation, spacy_remove_adverbs]
policy = ApplyAllPolicy(3, n_per_original=1, keep_original=True)

tf_applier = PandasTFApplier(tfs, policy)
policy.generate_for_example()
# Out:
# [[], [0, 1, 2]]

# %%
from snorkel.augmentation import *

tfs = [ predict_next, augment_by_translation, spacy_remove_adverbs]
policy =ApplyEachPolicy(len(tfs), keep_original=True)

tf_applier = PandasTFApplier(tfs, policy)
policy.generate_for_example()
# Out:
# [[], [0], [1], [2]]

# %%
from snorkel.augmentation import PandasTFApplier, ApplyOnePolicy

tfs = [ predict_next, augment_by_translation, spacy_remove_adverbs]
policy =ApplyOnePolicy(4, keep_original=True)

tf_applier = PandasTFApplier(tfs, policy)
policy.generate_for_example()
# Out:
# [[], [0], [0], [0], [0]]

# %%
from snorkel.augmentation import PandasTFApplier, RandomPolicy

tfs = [ predict_next, augment_by_translation, spacy_remove_adverbs]
policy =RandomPolicy(3, sequence_length =5, n_per_original = 2, keep_original=True)

tf_applier = PandasTFApplier(tfs, policy)
policy.generate_for_example()
# Out:
# [[], [1, 2, 1, 2, 2], [2, 1, 2, 0, 1]]

# %%
from snorkel.augmentation import PandasTFApplier, MeanFieldPolicy

tfs = [ predict_next, augment_by_translation, spacy_remove_adverbs]
policy = MeanFieldPolicy(
    len(tfs),
    sequence_length=1,
    n_per_original=1,
    keep_original=True,
    p=[0.3, 0.3, 0.4],
)

tf_applier = PandasTFApplier(tfs, policy)
policy.generate_for_example()
# Out:
# [[], [0], [0]]

# %%
from snorkel.augmentation import PandasTFApplier, MeanFieldPolicy

tfs = [ predict_next, augment_by_translation, spacy_remove_adverbs]
policy = MeanFieldPolicy(
    len(tfs),
    sequence_length=1,
    n_per_original=1,
    keep_original=True,
    p=[0.3, 0.3, 0.4],
)

tf_applier = PandasTFApplier(tfs, policy)
df_train_augmented = tf_applier.apply(df2)
# Out:
#   0%|                                                                                            | 0/7 [00:00<?, ?it/s]
# SPACY_REMOVE_ADVERBS
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     I simply adore this book and it's what made me...
# reviewer                                  L. Cortes "Book Junkie"
# Name: 2054, dtype: object
# SPACY_REMOVE_ADVERBS RETURN
# PREDICT_NEXT
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     Magic, mystery, romance and burglary are all p...
# reviewer                         Terry A. Benedict-Devine "Terry"
# Name: 2055, dtype: object
# INFO:tensorflow:Restoring parameters from C:\Users\sefilipi\Documents\books\snorkel\chapter 2\Data\gpt-2\models\774M\model.ckpt
#  29%|████████████████████████                                                            | 2/7 [01:07<02:48, 33.77s/it]
# AUGMENT_BY_TRANSLATION
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     I read the review and got the book and fell in...
# reviewer                                            Diana Faraone
# Name: 2056, dtype: object
# C:\Users\sefilipi\AppData\Local\Continuum\anaconda3\envs\GPT2\lib\site-packages\ipykernel_launcher.py:26: UserWarning: [W007] The model you're using has no word vectors loaded, so the result of the Doc.similarity method will be based on the tagger, parser and NER, which may not give useful similarity judgements. This may happen if you're using one of the small models, e.g. `en_core_web_sm`, which don't ship with word vectors and only use context-sensitive tensors. You can always add your own word vectors, or use one of the larger models instead if available.
# AUGMENT_BY_TRANSLATION RETURN
#  43%|████████████████████████████████████                                                | 3/7 [01:11<01:24, 21.21s/it]
# AUGMENT_BY_TRANSLATION
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     It is difficult to find books in this genre th...
# reviewer                                                A. Rowley
# Name: 2057, dtype: object
# AUGMENT_BY_TRANSLATION RETURN
#  57%|████████████████████████████████████████████████                                    | 4/7 [01:13<00:41, 13.99s/it]
# SPACY_REMOVE_ADVERBS
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     This is one of my favorite Nora Roberts book. ...
# reviewer                                   avid reader "A reader"
# Name: 2058, dtype: object
# SPACY_REMOVE_ADVERBS RETURN
# PREDICT_NEXT
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     This book has everything....Love, Greed, Murde...
# reviewer                                              S. Williams
# Name: 2059, dtype: object
# INFO:tensorflow:Restoring parameters from C:\Users\sefilipi\Documents\books\snorkel\chapter 2\Data\gpt-2\models\774M\model.ckpt
#  86%|████████████████████████████████████████████████████████████████████████            | 6/7 [01:59<00:18, 18.78s/it]
# PREDICT_NEXT
# product_name                Honest Illusions: Books: Nora Roberts
# review_text     When I began to read Nora Roberts, I really di...
# reviewer                                              Creekergirl
# Name: 2060, dtype: object
# INFO:tensorflow:Restoring parameters from C:\Users\sefilipi\Documents\books\snorkel\chapter 2\Data\gpt-2\models\774M\model.ckpt
# 100%|████████████████████████████████████████████████████████████████████████████████████| 7/7 [02:42<00:00, 23.21s/it]

# %%
df2
# Out:
#                                product_name  \
# 2054  Honest Illusions: Books: Nora Roberts
# 2055  Honest Illusions: Books: Nora Roberts
# 2056  Honest Illusions: Books: Nora Roberts
# 2057  Honest Illusions: Books: Nora Roberts
# 2058  Honest Illusions: Books: Nora Roberts
# 2059  Honest Illusions: Books: Nora Roberts
# 2060  Honest Illusions: Books: Nora Roberts
#
#                                             review_text  \
# 2054  I simply adore this book and it's what made me...
# 2055  Magic, mystery, romance and burglary are all p...
# 2056  I read the review and got the book and fell in...
# 2057  It is difficult to find books in this genre th...
# 2058  This is one of my favorite Nora Roberts book. ...
# 2059  This book has everything....Love, Greed, Murde...
# 2060  When I began to read Nora Roberts, I really di...
#
#                               reviewer
# 2054           L. Cortes "Book Junkie"
# 2055  Terry A. Benedict-Devine "Terry"
# 2056                     Diana Faraone
# 2057                         A. Rowley
# 2058            avid reader "A reader"
# 2059                       S. Williams
# 2060                       Creekergirl

# %%
df_train_augmented
# Out:
#                                product_name  \
# 2054  Honest Illusions: Books: Nora Roberts
# 2054  Honest Illusions: Books: Nora Roberts
# 2054  Honest Illusions: Books: Nora Roberts
# 2055  Honest Illusions: Books: Nora Roberts
# 2055  Honest Illusions: Books: Nora Roberts
# 2055  Honest Illusions: Books: Nora Roberts
# 2056  Honest Illusions: Books: Nora Roberts
# 2056  Honest Illusions: Books: Nora Roberts
# 2056  Honest Illusions: Books: Nora Roberts
# 2057  Honest Illusions: Books: Nora Roberts
# 2057  Honest Illusions: Books: Nora Roberts
# 2057  Honest Illusions: Books: Nora Roberts
# 2058  Honest Illusions: Books: Nora Roberts
# 2058  Honest Illusions: Books: Nora Roberts
# 2058  Honest Illusions: Books: Nora Roberts
# 2059  Honest Illusions: Books: Nora Roberts
# 2059  Honest Illusions: Books: Nora Roberts
# 2059  Honest Illusions: Books: Nora Roberts
# 2060  Honest Illusions: Books: Nora Roberts
# 2060  Honest Illusions: Books: Nora Roberts
# 2060  Honest Illusions: Books: Nora Roberts
#
#                                             review_text  \
# 2054  I simply adore this book and it's what made me...
# 2054  I love this book and that's what made me come ...
# 2054  I love this book and that's what made me come ...
# 2055  Magic, mystery, romance and burglary are all p...
# 2055  Magic , mystery , romance and burglary are all...
# 2055  Magic , mystery , romance and burglary are all...
# 2056  I read the review and got the book and fell in...
# 2056  I read the review and got the book and fell in...
# 2056  I read the review and got the book and fell in...
# 2057  It is difficult to find books in this genre th...
# 2057  It is difficult to find books in this genre th...
# 2057  It's hard to find books like this that have a ...
# 2058  This is one of my favorite Nora Roberts book. ...
# 2058  It's one of my favorite Nora Roberts books. ."...
# 2058  It 's one of my favorite Nora Roberts books . ...
# 2059  This book has everything....Love, Greed, Murde...
# 2059  This book has it all.   One thing I really lik...
# 2059  This book has everything.   Some characters we...
# 2060  When I began to read Nora Roberts, I really di...
# 2060  I began to read Nora Roberts , I did n't expec...
# 2060  I began to read Nora Roberts , I did n't expec...
#
#                               reviewer
# 2054           L. Cortes "Book Junkie"
# 2054           L. Cortes "Book Junkie"
# 2054           L. Cortes "Book Junkie"
# 2055  Terry A. Benedict-Devine "Terry"
# 2055  Terry A. Benedict-Devine "Terry"
# 2055  Terry A. Benedict-Devine "Terry"
# 2056                     Diana Faraone
# 2056                     Diana Faraone
# 2056                     Diana Faraone
# 2057                         A. Rowley
# 2057                         A. Rowley
# 2057                         A. Rowley
# 2058            avid reader "A reader"
# 2058            avid reader "A reader"
# 2058            avid reader "A reader"
# 2059                       S. Williams
# 2059                       S. Williams
# 2059                       S. Williams
# 2060                       Creekergirl
# 2060                       Creekergirl
# 2060                       Creekergirl
